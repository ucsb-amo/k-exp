# %%
import numpy as np

img_amps = [0., .2,.4,.8,]
lightshifts = [0.,30.e3,63.e3,138.35e3]

import matplotlib.pyplot as plt

x = np.asarray(img_amps, dtype=float)
y = np.asarray(lightshifts, dtype=float)

if x.size != y.size:
    n = min(x.size, y.size)
    print(f'Length mismatch: using first {n} points.')
    x = x[:n]
    y = y[:n]

m, b = np.polyfit(x, y, 1)

def lightshift_from_img_amp(img_amp):
    return m * np.asarray(img_amp) + b

xfit = np.linspace(x.min(), x.max(), 200)
yfit = lightshift_from_img_amp(xfit)

plt.figure()
plt.plot(x, y, 'o', label='data')
plt.plot(xfit, yfit, '-', label=f'fit: y = {m:.3e} x + {b:.3e}')
plt.xlabel('img_amp')
plt.ylabel('lightshift (Hz)')
plt.legend()
plt.tight_layout()

print(f'lightshift(img_amp) = {m:.6e} * img_amp + {b:.6e}  [Hz]')
# Out:
# lightshift(img_amp) = 1.740214e+05 * img_amp + -3.070000e+03  [Hz]

# %%
lightshift_from_img_amp(.2)
# Out:
# np.float64(35157.142857142906)

# %%
img_amps = np.linspace(.2,2.5,50)
imgs = np.array([.1,.15,.2,.25,.3,.35,.4,.8])

119.4642e6 + lightshift_from_img_amp(img_amps)
# Out:
# array([1.19495934e+08, 1.19504103e+08, 1.19512271e+08, 1.19520439e+08,
#        1.19528608e+08, 1.19536776e+08, 1.19544944e+08, 1.19553113e+08,
#        1.19561281e+08, 1.19569449e+08, 1.19577618e+08, 1.19585786e+08,
#        1.19593955e+08, 1.19602123e+08, 1.19610291e+08, 1.19618460e+08,
#        1.19626628e+08, 1.19634796e+08, 1.19642965e+08, 1.19651133e+08,
#        1.19659301e+08, 1.19667470e+08, 1.19675638e+08, 1.19683806e+08,
#        1.19691975e+08, 1.19700143e+08, 1.19708311e+08, 1.19716480e+08,
#        1.19724648e+08, 1.19732817e+08, 1.19740985e+08, 1.19749153e+08,
#        1.19757322e+08, 1.19765490e+08, 1.19773658e+08, 1.19781827e+08,
#        1.19789995e+08, 1.19798163e+08, 1.19806332e+08, 1.19814500e+08,
#        1.19822668e+08, 1.19830837e+08, 1.19839005e+08, 1.19847173e+08,
#        1.19855342e+08, 1.19863510e+08, 1.19871679e+08, 1.19879847e+08,
#        1.19888015e+08, 1.19896184e+08])

# %%
np.linspace(.2,1.9,50)
# Out:
# array([0.2       , 0.23469388, 0.26938776, 0.30408163, 0.33877551,
#        0.37346939, 0.40816327, 0.44285714, 0.47755102, 0.5122449 ,
#        0.54693878, 0.58163265, 0.61632653, 0.65102041, 0.68571429,
#        0.72040816, 0.75510204, 0.78979592, 0.8244898 , 0.85918367,
#        0.89387755, 0.92857143, 0.96326531, 0.99795918, 1.03265306,
#        1.06734694, 1.10204082, 1.13673469, 1.17142857, 1.20612245,
#        1.24081633, 1.2755102 , 1.31020408, 1.34489796, 1.37959184,
#        1.41428571, 1.44897959, 1.48367347, 1.51836735, 1.55306122,
#        1.5877551 , 1.62244898, 1.65714286, 1.69183673, 1.72653061,
#        1.76122449, 1.79591837, 1.83061224, 1.86530612, 1.9       ])

# %%
import numpy as np

img_amps = [0.,.2,.4,.8]
lightshifts = [0.,30.5e3,60.e3,120.e3]

import matplotlib.pyplot as plt

x = np.asarray(img_amps, dtype=float)
y = np.asarray(lightshifts, dtype=float)

if x.size != y.size:
    n = min(x.size, y.size)
    print(f'Length mismatch: using first {n} points.')
    x = x[:n]
    y = y[:n]

m, b = np.polyfit(x, y, 1)

def lightshift_from_img_amp(img_amp):
    return m * np.asarray(img_amp) + b

xfit = np.linspace(x.min(), x.max(), 200)
yfit = lightshift_from_img_amp(xfit)

plt.figure()
plt.plot(x, y, 'o', label='data')
plt.plot(xfit, yfit, '-', label=f'fit: y = {m:.3e} x + {b:.3e}')
plt.xlabel('img_amp')
plt.ylabel('lightshift (Hz)')
plt.legend()
plt.tight_layout()

print(f'lightshift(img_amp) = {m:.6e} * img_amp + {b:.6e}  [Hz]')
# Out:
# lightshift(img_amp) = 1.497857e+05 * img_amp + 2.000000e+02  [Hz]

# %%
lightshift_from_img_amp(2.5)
# Out:
# np.float64(374664.28571428574)

# %%
img_amps = np.linspace(.2,2.5,50)

119.4642e6 + lightshift_from_img_amp(img_amps)
# Out:
# array([1.19494357e+08, 1.19501388e+08, 1.19508419e+08, 1.19515449e+08,
#        1.19522480e+08, 1.19529511e+08, 1.19536542e+08, 1.19543572e+08,
#        1.19550603e+08, 1.19557634e+08, 1.19564665e+08, 1.19571695e+08,
#        1.19578726e+08, 1.19585757e+08, 1.19592788e+08, 1.19599819e+08,
#        1.19606849e+08, 1.19613880e+08, 1.19620911e+08, 1.19627942e+08,
#        1.19634972e+08, 1.19642003e+08, 1.19649034e+08, 1.19656065e+08,
#        1.19663095e+08, 1.19670126e+08, 1.19677157e+08, 1.19684188e+08,
#        1.19691218e+08, 1.19698249e+08, 1.19705280e+08, 1.19712311e+08,
#        1.19719341e+08, 1.19726372e+08, 1.19733403e+08, 1.19740434e+08,
#        1.19747464e+08, 1.19754495e+08, 1.19761526e+08, 1.19768557e+08,
#        1.19775587e+08, 1.19782618e+08, 1.19789649e+08, 1.19796680e+08,
#        1.19803710e+08, 1.19810741e+08, 1.19817772e+08, 1.19824803e+08,
#        1.19831834e+08, 1.19838864e+08])

# %%
img_amps = np.linspace(.5,1.5,50)

119.4642e6 + lightshift_from_img_amp(img_amps)
# Out:
# array([1.19539293e+08, 1.19542350e+08, 1.19545407e+08, 1.19548463e+08,
#        1.19551520e+08, 1.19554577e+08, 1.19557634e+08, 1.19560691e+08,
#        1.19563748e+08, 1.19566805e+08, 1.19569861e+08, 1.19572918e+08,
#        1.19575975e+08, 1.19579032e+08, 1.19582089e+08, 1.19585146e+08,
#        1.19588202e+08, 1.19591259e+08, 1.19594316e+08, 1.19597373e+08,
#        1.19600430e+08, 1.19603487e+08, 1.19606544e+08, 1.19609600e+08,
#        1.19612657e+08, 1.19615714e+08, 1.19618771e+08, 1.19621828e+08,
#        1.19624885e+08, 1.19627942e+08, 1.19630998e+08, 1.19634055e+08,
#        1.19637112e+08, 1.19640169e+08, 1.19643226e+08, 1.19646283e+08,
#        1.19649340e+08, 1.19652396e+08, 1.19655453e+08, 1.19658510e+08,
#        1.19661567e+08, 1.19664624e+08, 1.19667681e+08, 1.19670737e+08,
#        1.19673794e+08, 1.19676851e+08, 1.19679908e+08, 1.19682965e+08,
#        1.19686022e+08, 1.19689079e+08])

# %%
119.4641e6 + lightshift_from_img_amp(.3)
# Out:
# np.float64(119573183.33333333)

# %%
img_amps = np.linspace(.2,2.5,50)

# %%
img_amps
# Out:
# array([0.2       , 0.24693878, 0.29387755, 0.34081633, 0.3877551 ,
#        0.43469388, 0.48163265, 0.52857143, 0.5755102 , 0.62244898,
#        0.66938776, 0.71632653, 0.76326531, 0.81020408, 0.85714286,
#        0.90408163, 0.95102041, 0.99795918, 1.04489796, 1.09183673,
#        1.13877551, 1.18571429, 1.23265306, 1.27959184, 1.32653061,
#        1.37346939, 1.42040816, 1.46734694, 1.51428571, 1.56122449,
#        1.60816327, 1.65510204, 1.70204082, 1.74897959, 1.79591837,
#        1.84285714, 1.88979592, 1.93673469, 1.98367347, 2.03061224,
#        2.07755102, 2.1244898 , 2.17142857, 2.21836735, 2.26530612,
#        2.3122449 , 2.35918367, 2.40612245, 2.45306122, 2.5       ])
