# %%
from artiq.experiment import *
import numpy as np
from subprocess import PIPE, run
import matplotlib.pyplot as plt
import os
import textwrap
from waxx.control import ethernet_relay
from artiq.experiment import *

class ExptBuilder():
    def __init__(self):
        self.__code_path__ = os.environ.get('code')
        self.__temp_exp_path__ = os.path.join(self.__code_path__, "k-exp", "kexp", "experiments", "ml_expt.py")

    def run_expt(self):
        expt_path = self.__temp_exp_path__
        run_expt_command = r"%kpy% & ar " + expt_path
        result = run(run_expt_command, stdout=PIPE, stderr=PIPE, universal_newlines=True, shell=True)
        print(result.returncode, result.stdout, result.stderr)
        os.remove(self.__temp_exp_path__)
        return result.returncode
    
    def write_experiment_to_file(self, program):
        with open(self.__temp_exp_path__, 'w') as file:
            file.write(program)
    
    def fringe_scan_expt(self, img_amp, t_raman_pulse):
        script = textwrap.dedent(f"""
        from artiq.experiment import *
        from artiq.experiment import delay
        from kexp import Base, img_types, cameras
        import numpy as np
        from kexp.calibrations.tweezer import tweezer_vpd1_to_vpd2
        from kexp.calibrations.imaging import high_field_imaging_detuning
        from artiq.coredevice.sampler import Sampler
        from artiq.language import now_mu
        from kexp.util.artiq.async_print import aprint

        class hf_monitored_rabi(EnvExperiment, Base):

            def prepare(self):
                Base.__init__(self,setup_camera=False,
                            camera_select=cameras.andor,
                            save_data=True,
                            imaging_type=img_types.DISPERSIVE)

                self.p.v_pd_hf_tweezer_squeeze_power = 1.97
                                 
                # self.p.frequency_raman_transition = 

                self.p.t_raman_pulse = {t_raman_pulse}

                self.p.t_continuous_rabi = 2000.e-6
                
                self.p.amp_imaging = {img_amp}
                
                self.p.dimension_slm_mask = 20.e-6

                self.p.phase_slm_mask = 0.42 * np.pi

                self.p.t_tweezer_hold = 15.e-3

                self.p.t_tof = 20.e-6
                
                self.p.t_mot_load = 1.0
                
                self.p.N_repeats = 100

                self.scope = self.scope_data.add_siglent_scope("192.168.1.108", label='PD', arm=False)

                self.finish_prepare(shuffle=True)

            @kernel
            def scan_kernel(self):
                
                self.set_imaging_detuning(frequency_detuned = self.p.frequency_detuned_hf_midpoint)
                self.slm.write_phase_mask_kernel(phase=self.p.phase_slm_mask,dimension=self.p.dimension_slm_mask)
                self.imaging.set_power(self.p.amp_imaging)
        
                self.prepare_hf_tweezers(ramp_down_painting=False,squeeze=False)
        
                self.raman.init(fraction_power = self.p.fraction_power_raman,
                                frequency_transition = self.p.frequency_raman_transition)
        
                self.ttl.raman_shutter.on()
                delay(10.e-3)
                self.ttl.line_trigger.wait_for_line_trigger()
                delay(4.7e-3)
        
                self.raman.pulse(t=self.p.t_raman_pulse)
                
                self.ttl.pd_scope_trig3.pulse(1.e-6)
                self.imaging.on()
                delay(self.p.t_continuous_rabi)
                self.imaging.off()
        
                self.ttl.raman_shutter.off()
                
                self.set_imaging_detuning(frequency_detuned = self.p.frequency_detuned_hf_f1m1)
                self.imaging.set_power(.2,reset_pid=True)
        
                delay(self.p.t_tweezer_hold)
                self.tweezer.off()
        
                delay(self.p.t_tof)
        
                self.abs_image()
        
                self.core.wait_until_mu(now_mu())
                self.scope.read_sweep(0)
                self.core.break_realtime()
                delay(30.e-3)

            @kernel
            def run(self):
                self.init_kernel()
                self.load_2D_mot(self.p.t_2D_mot_load_delay)
                self.scan()
                self.mot_observe()

            def analyze(self):
                import os
                expt_filepath = os.path.abspath(__file__)
                # aprint(self.scope._data)
                self.end(expt_filepath)
                """)
        return script

# %%
eBuilder = ExptBuilder()

# %%
img_amp = np.linspace(.2,1.2,5)

t_raman_pulse = np.array([0.,self.p.t_raman_pi_pulse / 2])

repeats_of_repeats = 5

for i in range(len(img_amp)):
    for t in range(len(t_raman_pulse)):
        for r in range(repeats_of_repeats):
            print(img_amp[i],t_raman_pulse[t],'repeat of repeat #',r+1)
            eBuilder.write_experiment_to_file(eBuilder.fringe_scan_expt(img_amp=img_amp[i],t_raman_pulse=t_raman_pulse[t]))
            eBuilder.run_expt()
# Out:
# 0.2 0.0 repeat of repeat # 1
# 0  100 values of dummy. 100 total shots.
# Run ID: 74891
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74891
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 1/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 2/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 3/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 4/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 5/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 6/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 7/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 8/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 9/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 10/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 11/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 12/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 13/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 14/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 15/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 16/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 17/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 18/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 19/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 20/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 21/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 22/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 23/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 24/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 25/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 26/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 27/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 28/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 29/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 30/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 31/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 32/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 33/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 34/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 35/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 36/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 37/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 38/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 39/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 40/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 41/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 42/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 43/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 44/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 45/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 46/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 47/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 48/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 49/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 50/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 51/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 52/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 53/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 54/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 55/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 56/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 57/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 58/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 59/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 60/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 61/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 62/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 63/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 64/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 65/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 66/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 67/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 68/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 69/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 70/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 71/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 72/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 73/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 74/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 75/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 76/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 77/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 78/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 79/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 80/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 81/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 82/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 83/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 84/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 85/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 86/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 87/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 88/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 89/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 90/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 91/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 92/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 93/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 94/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 95/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 96/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 97/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 98/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 99/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 100/100 done
# [end_wax] called, run_id=74891
# [end_wax] scope_data closed
# [end_wax] cleanup_scanned complete
# Device states updated.
# run id 74891 complete at 2026-08-09 18:39:32  (ml_expt)
#
# 0.2 0.0 repeat of repeat # 2
# 0  100 values of dummy. 100 total shots.
# Run ID: 74892
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74892
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 1/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 2/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 3/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 4/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 5/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 6/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 7/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 8/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 9/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 10/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 11/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 12/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 13/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 14/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 15/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 16/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 17/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 18/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 19/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 20/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 21/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 22/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 23/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 24/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 25/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 26/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 27/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 28/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 29/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 30/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 31/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 32/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 33/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 34/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 35/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 36/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 37/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 38/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 39/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 40/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 41/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 42/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 43/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 44/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 45/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 46/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 47/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 48/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 49/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 50/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 51/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 52/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 53/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 54/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 55/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 56/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 57/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 58/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 59/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 60/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 61/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 62/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 63/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 64/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 65/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 66/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 67/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 68/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 69/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 70/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 71/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 72/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 73/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 74/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 75/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 76/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 77/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 78/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 79/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 80/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 81/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 82/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 83/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 84/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 85/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 86/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 87/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 88/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 89/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 90/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 91/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 92/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 93/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 94/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 95/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 96/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 97/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 98/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 99/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 100/100 done
# [end_wax] called, run_id=74892
# [end_wax] scope_data closed
# [end_wax] cleanup_scanned complete
# Device states updated.
# run id 74892 complete at 2026-08-09 18:53:27  (ml_expt)
#
# 0.2 0.0 repeat of repeat # 3
# 0  100 values of dummy. 100 total shots.
# Run ID: 74893
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74893
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 1/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 2/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 3/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 4/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
# shot 5/100 done
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
# ...
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# 1.2 5.094e-06 repeat of repeat # 1
# 1  100 values of dummy. 100 total shots.
# Run ID: 74936
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74936
#  Core Device Traceback:
# Traceback (most recent call first):
#   File "C:\Users\jarjarbinks\code\wax\waxx-src\waxx\control\tweezer\spectrum_DDS_tweezer.py", line 711, in awg_init
#     self.dds.data_transfer_mode(spcm.SPCM_DDS_DTM_DMA)
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\base\base.py", line 106, in ... kexp.base.base.Base.init_kernel<artiq_run_ml_expt.hf_monitored_rabi>(...) (RA=+0x8f8)
#     self.tweezer.awg_init()
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\experiments\ml_expt.py", line 89, in artiq_run_ml_expt.hf_monitored_rabi.run(..., ...) (RA=+0x150)
#     self.init_kernel()
# spcm.classes_error_exception.SpcmException(380): Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# 1.2 5.094e-06 repeat of repeat # 2
# 1  100 values of dummy. 100 total shots.
# Run ID: 74937
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74937
#  Core Device Traceback:
# Traceback (most recent call first):
#   File "C:\Users\jarjarbinks\code\wax\waxx-src\waxx\control\tweezer\spectrum_DDS_tweezer.py", line 711, in awg_init
#     self.dds.data_transfer_mode(spcm.SPCM_DDS_DTM_DMA)
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\base\base.py", line 106, in ... kexp.base.base.Base.init_kernel<artiq_run_ml_expt.hf_monitored_rabi>(...) (RA=+0x8f8)
#     self.tweezer.awg_init()
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\experiments\ml_expt.py", line 89, in artiq_run_ml_expt.hf_monitored_rabi.run(..., ...) (RA=+0x150)
#     self.init_kernel()
# spcm.classes_error_exception.SpcmException(380): Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# 1.2 5.094e-06 repeat of repeat # 3
# 1  100 values of dummy. 100 total shots.
# Run ID: 74938
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74938
#  Core Device Traceback:
# Traceback (most recent call first):
#   File "C:\Users\jarjarbinks\code\wax\waxx-src\waxx\control\tweezer\spectrum_DDS_tweezer.py", line 711, in awg_init
#     self.dds.data_transfer_mode(spcm.SPCM_DDS_DTM_DMA)
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\base\base.py", line 106, in ... kexp.base.base.Base.init_kernel<artiq_run_ml_expt.hf_monitored_rabi>(...) (RA=+0x8f8)
#     self.tweezer.awg_init()
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\experiments\ml_expt.py", line 89, in artiq_run_ml_expt.hf_monitored_rabi.run(..., ...) (RA=+0x150)
#     self.init_kernel()
# spcm.classes_error_exception.SpcmException(380): Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# 1.2 5.094e-06 repeat of repeat # 4
# 1  100 values of dummy. 100 total shots.
# Run ID: 74939
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74939
#  Core Device Traceback:
# Traceback (most recent call first):
#   File "C:\Users\jarjarbinks\code\wax\waxx-src\waxx\control\tweezer\spectrum_DDS_tweezer.py", line 711, in awg_init
#     self.dds.data_transfer_mode(spcm.SPCM_DDS_DTM_DMA)
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\base\base.py", line 106, in ... kexp.base.base.Base.init_kernel<artiq_run_ml_expt.hf_monitored_rabi>(...) (RA=+0x8f8)
#     self.tweezer.awg_init()
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\experiments\ml_expt.py", line 89, in artiq_run_ml_expt.hf_monitored_rabi.run(..., ...) (RA=+0x150)
#     self.init_kernel()
# spcm.classes_error_exception.SpcmException(380): Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# 1.2 5.094e-06 repeat of repeat # 5
# 1  100 values of dummy. 100 total shots.
# Run ID: 74940
#
# Sent: {'mask': 'spot', 'center': [993, 818], 'phase': 0.42, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.42 pi, x-center = 993, y-center = 818
#
#  Run ID: 74940
#  Core Device Traceback:
# Traceback (most recent call first):
#   File "C:\Users\jarjarbinks\code\wax\waxx-src\waxx\control\tweezer\spectrum_DDS_tweezer.py", line 711, in awg_init
#     self.dds.data_transfer_mode(spcm.SPCM_DDS_DTM_DMA)
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\base\base.py", line 106, in ... kexp.base.base.Base.init_kernel<artiq_run_ml_expt.hf_monitored_rabi>(...) (RA=+0x8f8)
#     self.tweezer.awg_init()
#   File "C:\Users\jarjarbinks\code\k-exp\kexp\experiments\ml_expt.py", line 89, in artiq_run_ml_expt.hf_monitored_rabi.run(..., ...) (RA=+0x150)
#     self.init_kernel()
# spcm.classes_error_exception.SpcmException(380): Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed
#
# End of Core Device Traceback
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jarjarbinks\code\.venv\Scripts\artiq_run.exe\__main__.py", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 273, in main
#     return run(with_file=True)
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 257, in run
#     raise exn
#   File "C:\Users\jarjarbinks\code\artiq\artiq\frontend\artiq_run.py", line 249, in run
#     exp_inst.run()
#     ~~~~~~~~~~~~^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\language\core.py", line 54, in run_on_core
#     return getattr(self, arg).run(run_on_core, ((self,) + k_args), k_kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 177, in run
#     self._run_compiled(kernel_library, embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\core.py", line 166, in _run_compiled
#     self.comm.serve(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 744, in serve
#     self._serve_exception(embedding_map, symbolizer, demangler)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jarjarbinks\code\artiq\artiq\coredevice\comm_kernel.py", line 726, in _serve_exception
#     raise python_exn
# spcm.classes_error_exception.SpcmException: Call: (SPC_DDS_CMD, SPCM_DDS_CMD_WRITE_TO_CARD) -> value not allowed

# %%
from kexp import EthernetRelay
from waxx.util.guis.als.als_gui_client import ALSGuiClient
from waxx.util.guis.precilaser.precilaser_gui_client import PrecilaserGuiClient

relay = EthernetRelay()
relay.source_off()

als = ALSGuiClient()
ok = als.run_shutdown_sequence()

precilaser = PrecilaserGuiClient()
ok = precilaser.run_shutdown_sequence()
