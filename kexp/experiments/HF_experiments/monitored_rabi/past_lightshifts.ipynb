# %%
import matplotlib.pyplot as plt

og_good = [35.114e3, 454.010e3]
uncompressed = [33.47e3, 478.430e3]
comp_32 = [33.379e3, 474.525e3]
comp_64 = [28.e3, 338.583e3]
recent = [30.257e3, 374.764e3]
dilute_measured = [35.974e3, 499.374e3]
rn = [37.e3,462.e3]

plt.plot(og_good, label='Original Good')
plt.plot(uncompressed, label='Uncompressed')
plt.plot(comp_32, label='Compressed 32')
plt.plot(comp_64, label='Compressed 64')
plt.plot(recent, label='Recent')
plt.plot(dilute_measured, label='Dilute Measured')
plt.plot(rn, label='rn')
plt.legend()
