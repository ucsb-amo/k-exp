# %%
import numpy as np
from subprocess import PIPE, run
import matplotlib.pyplot as plt
import os
import textwrap
from waxx.control import ethernet_relay

class ExptBuilder():
    def __init__(self):
        self.__code_path__ = os.environ.get('code')
        self.__temp_exp_path__ = os.path.join(self.__code_path__, "k-exp", "kexp", "experiments", "ml_expt.py")

    def run_expt(self):
        expt_path = self.__temp_exp_path__
        run_expt_command = r"%kpy% & artiq_run " + expt_path
        result = run(run_expt_command, stdout=PIPE, stderr=PIPE, universal_newlines=True, shell=True)
        print(result.returncode, result.stdout, result.stderr)
        os.remove(self.__temp_exp_path__)
        return result.returncode
    
    def write_experiment_to_file(self, program):
        with open(self.__temp_exp_path__, 'w') as file:
            file.write(program)
    
    def fringe_scan_expt(self, img_amp, freq_raman):
        script = textwrap.dedent(f"""
        from artiq.experiment import *
        from artiq.experiment import delay
        from kexp import Base, img_types, cameras
        import numpy as np
        from kexp.calibrations.tweezer import tweezer_vpd1_to_vpd2
        from kexp.calibrations.imaging import high_field_imaging_detuning
        from artiq.coredevice.sampler import Sampler
        from artiq.language import now_mu
        from kexp.util.artiq.async_print import aprint

        class hf_monitored_rabi(EnvExperiment, Base):

            def prepare(self):
                Base.__init__(self,setup_camera=True,
                            camera_select=cameras.andor,
                            save_data=True,
                            imaging_type=img_types.DISPERSIVE)

                
                self.xvar('frequency_raman_transition',{freq_raman} + (1/(2*self.p.t_raman_pi_pulse)) * np.linspace(-2.,2.,13))

                self.p.t_continuous_rabi = 300.e-6

                # self.xvar('t_raman_pulse',[0, 8.7e-06 / 2, 8.7e-06])

                # self.xvar('t_raman_pulse',np.linspace(0.,8.7e-6,7))
                self.p.t_raman_pulse = 8.8699e-6
                
                # self.xvar('amp_imaging',np.linspace(0.2,1.,10))
                self.p.amp_imaging = {img_amp}

                self.p.hf_imaging_detuning = -568.e6 # 182.

                self.p.hf_imaging_detuning_mid = -514.e6 # -1 --> 0
                
                self.p.dimension_slm_mask = 20.e-6

                self.p.phase_slm_mask = 0.186 * np.pi

                self.p.t_tweezer_hold = 20.e-3

                self.p.t_tof = 20.e-6
                
                self.p.t_mot_load = 1.0
                
                self.p.N_repeats = 10

                self.scope = self.scope_data.add_siglent_scope("192.168.1.108", label='PD', arm=False)

                self.finish_prepare(shuffle=True)

            @kernel
            def scan_kernel(self):
                
                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning_mid)
                # self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.slm.write_phase_mask_kernel(phase=self.p.phase_slm_mask,dimension=self.p.dimension_slm_mask)
                self.imaging.set_power(self.p.amp_imaging)

                self.prepare_hf_tweezers(squeeze=True)

                self.raman.init(fraction_power = self.p.fraction_power_raman,
                                frequency_transition = self.p.frequency_raman_transition)

                self.ttl.raman_shutter.on()
                delay(10.e-3)
                self.ttl.line_trigger.wait_for_line_trigger()
                delay(4.7e-3)

                # self.raman.pulse(t=self.p.t_raman_pulse)
                
                self.ttl.pd_scope_trig3.pulse(1.e-6)
                self.imaging.on()
                delay(3.e-6)
                self.raman.pulse(t=self.p.t_continuous_rabi)
                # delay(self.p.t_continuous_rabi)
                self.imaging.off()

                self.ttl.raman_shutter.off()
                
                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.imaging.set_power(.2,reset_pid=True)

                delay(self.p.t_tweezer_hold)
                self.tweezer.off()

                delay(self.p.t_tof)

                self.abs_image()

                self.core.wait_until_mu(now_mu())
                self.scope.read_sweep(0)
                self.core.break_realtime()
                delay(30.e-3)

            @kernel
            def run(self):
                self.init_kernel()
                self.load_2D_mot(self.p.t_2D_mot_load_delay)
                self.scan()
                self.mot_observe()

            def analyze(self):
                import os
                expt_filepath = os.path.abspath(__file__)
                # aprint(self.scope._data)
                self.end(expt_filepath)
                """)
        return script

# %%
eBuilder = ExptBuilder()

# %%
img_amp = np.linspace(2.45,3.5, 15)
# np.random.shuffle(ts)
freq_raman = np.array([1.19699500e+08, 1.19706764e+08, 1.19714029e+08, 1.19721293e+08,
       1.19728557e+08, 1.19735821e+08, 1.19743086e+08, 1.19750350e+08,
       1.19757614e+08, 1.19764879e+08, 1.19772143e+08, 1.19779407e+08,
       1.19786671e+08, 1.19793936e+08, 1.19801200e+08])
for f in range(20):
    print(img_amp[f],freq_raman[f])
    eBuilder.write_experiment_to_file(eBuilder.fringe_scan_expt(img_amp=img_amp[f],freq_raman = freq_raman[f]))
    eBuilder.run_expt()
# Out:
# 2.45 119699500.0
# 0 Run id: 63548
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063548_2026-04-12_11-14-06_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63548
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.5250000000000004 119706764.0
# 0 Run id: 63549
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063549_2026-04-12_11-15-31_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63549
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.6 119714029.0
# 0 Run id: 63550
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063550_2026-04-12_11-16-54_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63550
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.6750000000000003 119721293.0
# 0 Run id: 63551
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063551_2026-04-12_11-18-18_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63551
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.75 119728557.0
# 0 Run id: 63552
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063552_2026-04-12_11-19-42_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63552
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.825 119735821.0
# 0 Run id: 63553
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063553_2026-04-12_11-21-05_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63553
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.9 119743086.0
# 0 Run id: 63554
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063554_2026-04-12_11-22-29_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63554
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 2.975 119750350.0
# 0 Run id: 63555
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063555_2026-04-12_11-23-52_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63555
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.05 119757614.0
# 0 Run id: 63556
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063556_2026-04-12_11-25-16_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63556
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.125 119764879.0
# 0 Run id: 63557
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063557_2026-04-12_11-26-38_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63557
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.2 119772143.0
# 0 Run id: 63558
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063558_2026-04-12_11-28-01_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63558
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.275 119779407.0
# 0 Run id: 63559
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063559_2026-04-12_11-29-24_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63559
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.35 119786671.0
# 0 Run id: 63560
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063560_2026-04-12_11-30-47_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63560
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.425 119793936.0
# 0 Run id: 63561
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063561_2026-04-12_11-32-09_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63561
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 3.5 119801200.0
# 0 Run id: 63562
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-04-12\0063562_2026-04-12_11-33-31_hf_monitored_rabi.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#  Run ID: 63562
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.186, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.186 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 8
#       3 freq_raman = np.array([1.19699500e+08, 1.19706764e+08, 1.19714029e+08, 1.19721293e+08,
#       4        1.19728557e+08, 1.19735821e+08, 1.19743086e+08, 1.19750350e+08,
#       5        1.19757614e+08, 1.19764879e+08, 1.19772143e+08, 1.19779407e+08,
#       6        1.19786671e+08, 1.19793936e+08, 1.19801200e+08])
#       7 for f in range(20):
# ----> 8     print(img_amp[f],freq_raman[f])
#       9     eBuilder.write_experiment_to_file(eBuilder.fringe_scan_expt(img_amp=img_amp[f],freq_raman = freq_raman[f]))
#      10     eBuilder.run_expt()
#
# IndexError: index 15 is out of bounds for axis 0 with size 15
