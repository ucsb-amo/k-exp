# %%
# import vars 
import integration.hf_exp as lib
import os
import numpy as np

from kexp.config import ExptParams

p = ExptParams()

# %%
var_dict = {'i_hf_tweezer_evap1_current': {'initial': 193.5, 'range': [191.0, 195.0]},
 'i_hf_tweezer_evap2_current': {'initial': 193.0, 'range': [192.0, 195.0]},
 'i_hf_tweezer_load_current': {'initial': 193.5, 'range': [190.0, 195.0]},
 't_hf_tweezer_1064_rampdown': {'initial': 0.2, 'range': [0.02, 0.5]},
 't_hf_tweezer_1064_rampdown2': {'initial': 0.7, 'range': [0.05, 1.0]},
 'v_hf_tweezer_paint_amp_max': {'initial': -1.7, 'range': [-4.0, 1.0]},
 'v_pd_hf_tweezer_1064_ramp_end': {'initial': 9.2, 'range': [4.0, 9.5]},
 'v_pd_hf_tweezer_1064_rampdown2_end': {'initial': 0.17, 'range': [0.07, 0.18]},
 'v_pd_hf_tweezer_1064_rampdown_end': {'initial': 1.13, 'range': [0.5, 3.0]}}

# %%
# generate lists of parameter ranges and initial values to feed to MLOOP controller

init_params = [entry['initial'] for entry in var_dict.values()]
print(init_params)

ranges = [entry['range'] for entry in var_dict.values()]
print(ranges)

var_names = list(var_dict.keys())
# Out:
# [193.5, 193.0, 193.5, 0.2, 0.7, -1.7, 9.2, 0.17, 1.13]
# [[191.0, 195.0], [192.0, 195.0], [190.0, 195.0], [0.02, 0.5], [0.05, 1.0], [-4.0, 1.0], [4.0, 9.5], [0.07, 0.18], [0.5, 3.0]]

# %%
def main():
    #M-LOOP can be run with three commands
    
    #First create your interface
    interface = lib.CustomInterface(var_names)
    #Next create the controller. 
    #The controller must take the variables to be changed in the vars object
    #vars = Param()


    controller = lib.mlc.create_controller(interface, 
                                       controller_type = 'neural_net',  #type of controller to use, can be 'neural_network', 'gaussian process', 'differential evolution', 'random', 'nelder_mead''
                                       max_num_runs = 8000,
                                       target_cost = -109090000000,
                                       num_params = len(var_names),
                                       first_params = init_params, 
                                       min_boundary = np.transpose(ranges)[0],
                                       max_boundary = np.transpose(ranges)[1],
                                       interface_file_type = 'txt',               #file types of *exp_input.mat* and *exp_output.mat*
                                       controller_archive_file_type = 'txt',      #file type of the controller archive
                                       learner_archive_file_type = 'txt')      #file type of the learner archive
    controller.optimize()

main()
# Out:
# INFO     Optimization started.
# INFO     Run: 0 (training)
# INFO     params [ 1.935e+02  1.930e+02  1.935e+02  2.000e-01  7.000e-01 -1.700e+00
#   9.200e+00  1.700e-01  1.130e+00]
# 0 Run id: 50940
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50940
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50940.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -17.734156466188963
# INFO     cost -17.734156466188963 +/- 0.0
# INFO     Run: 1 (training)
# INFO     params [ 1.92880006e+02  1.94190553e+02  1.93022048e+02  3.33190909e-01
#   4.10378374e-01 -9.47861063e-01  8.66811680e+00  8.78747059e-02
#   1.44681290e+00]
# 0 Run id: 50941
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50941
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50941.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -9.32640737915023
# INFO     cost -9.32640737915023 +/- 0.0
# INFO     Run: 2 (training)
# INFO     params [ 1.93714775e+02  1.94871238e+02  1.92013430e+02  1.25220881e-01
#   1.94250578e-01 -2.17396981e+00  8.16480275e+00  9.70911462e-02
#   7.60697796e-01]
# 0 Run id: 50942
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50942
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50942.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -9.463377180001585
# INFO     cost -9.463377180001585 +/- 0.0
# INFO     Run: 3 (training)
# INFO     params [ 1.92999326e+02  1.93264181e+02  1.91865253e+02  3.36181860e-01
#   9.88331439e-01 -3.34605314e+00  4.85138749e+00  1.25339831e-01
#   2.48248783e+00]
# 0 Run id: 50943
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50943
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50943.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -8.895653854512055
# INFO     cost -8.895653854512055 +/- 0.0
# INFO     Run: 4 (training)
# INFO     params [ 1.91781489e+02  1.93164963e+02  1.94307213e+02  4.95650487e-01
#   2.34325336e-01 -3.43429352e-01  7.03303942e+00  1.56863745e-01
#   2.15196747e+00]
# 0 Run id: 50944
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50944
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50944.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -11.178276936210041
# INFO     cost -11.178276936210041 +/- 0.0
# INFO     Run: 5 (training)
# INFO     params [1.91227263e+02 1.94998569e+02 1.92395371e+02 3.30420970e-01
#  6.52444872e-02 1.40282141e-01 6.82586870e+00 1.71223013e-01
#  1.41452479e+00]
# 0 Run id: 50945
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50945
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50945.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -7.534218067011959
# INFO     cost -7.534218067011959 +/- 0.0
# INFO     Run: 6 (training)
# INFO     params [ 1.94287860e+02  1.94275539e+02  1.91708743e+02  1.63971090e-01
#   2.55600991e-01 -2.97691107e+00  5.77456984e+00  1.79086738e-01
#   2.44158134e+00]
# 0 Run id: 50946
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50946
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50946.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -9.397569932111097
# INFO     cost -9.397569932111097 +/- 0.0
# INFO     Run: 7 (training)
# INFO     params [ 1.93770233e+02  1.93404411e+02  1.93574137e+02  2.82199091e-01
#   3.16152833e-01 -9.82817931e-01  8.62390157e+00  1.46724632e-01
#   7.44048639e-01]
# 0 Run id: 50947
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50947
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50947.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -12.560321259971033
# INFO     cost -12.560321259971033 +/- 0.0
# INFO     Run: 8 (training)
# INFO     params [ 1.94555330e+02  1.92435837e+02  1.94890291e+02  3.20125858e-01
#   6.23166396e-01 -2.89072645e+00  8.58694271e+00  1.12173044e-01
#   2.96110147e+00]
# 0 Run id: 50948
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50948
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50948.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -7.426144215661097
# INFO     cost -7.426144215661097 +/- 0.0
# INFO     Run: 9 (training)
# INFO     params [ 1.92676429e+02  1.92267297e+02  1.90009578e+02  2.63326247e-01
#   6.83292818e-01 -1.68896627e+00  5.02020356e+00  1.38213376e-01
#   6.49547723e-01]
# 0 Run id: 50949
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50949
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50949.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -10.560104642149646
# INFO     cost -10.560104642149646 +/- 0.0
# INFO     Run: 10 (training)
# INFO     params [ 1.91736031e+02  1.94711001e+02  1.91204081e+02  1.44701018e-01
#   4.62639166e-01 -7.32200566e-01  8.52389285e+00  1.63732389e-01
#   2.32580532e+00]
# WARNING  !!! Do not give the interrupt signal again !!!
#  M-LOOP stopped with keyboard interupt or system exit. Please wait at least 1 minute for the threads to safely shut down.
#
# WARNING  Closing down controller.
# INFO     Machine learning learner did not provide best and/or all minima.
# 0 Run id: 50950
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1034, 835], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1034, y-center = 835
#
#  Run ID: 50950
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 50950.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 50939.
# Using ROI loaded from run 50939.
# -9.225077659385187
# INFO     Optimization ended because:
# INFO     Results:
# INFO     	* Best parameters found: [ 1.935e+02  1.930e+02  1.935e+02  2.000e-01  7.000e-01 -1.700e+00
#   9.200e+00  1.700e-01  1.130e+00]
# INFO     	* Best cost returned: -17.734156466188963 +/- 0.0
# INFO     	* Best run index: 0
# INFO     M-LOOP Done.

# %%
#### uncomment this and run it if u wanna delete the logs


# import os, shutil
# # Specify the path of the file to be deleted
# folder = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_archives'
# file_path_2 = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_logs'

# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))

# for filename in os.listdir(file_path_2):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))
