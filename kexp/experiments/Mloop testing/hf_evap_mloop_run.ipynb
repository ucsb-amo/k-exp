# %%
# import vars 
import integration.hf_exp as lib
import os
import numpy as np

from kexp.config import ExptParams

p = ExptParams()

# %%
var_dict = {'v_pd_hf_lightsheet_rampdown_end': {'initial': p.v_pd_hf_lightsheet_rampdown_end, 'range': [.3, 2.0]},
            'v_hf_tweezer_paint_amp_max': {'initial': p.v_hf_tweezer_paint_amp_max, 'range': [-4.0, 1.0]},
            'i_hf_tweezer_load_current': {'initial': p.i_hf_tweezer_load_current, 'range': [190.0, 194.0]},
            't_hf_tweezer_1064_ramp': {'initial': p.t_hf_tweezer_1064_ramp, 'range': [0.02, 0.3]},
            'v_pd_hf_tweezer_1064_ramp_end': {'initial': p.v_pd_hf_tweezer_1064_ramp_end, 'range': [4.0, 9.5]},
            'i_hf_tweezer_evap1_current': {'initial': p.i_hf_tweezer_evap1_current, 'range': [191.0, 195.0]},
            't_hf_tweezer_1064_rampdown': {'initial': p.t_hf_tweezer_1064_rampdown, 'range': [0.02, 0.5]},
            'v_pd_hf_tweezer_1064_rampdown_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown_end, 'range': [0.3, 2.0]},
            'i_hf_tweezer_evap2_current': {'initial': p.i_hf_tweezer_evap2_current, 'range': [192.0, 195.0]},
            't_hf_tweezer_1064_rampdown2': {'initial': p.t_hf_tweezer_1064_rampdown2, 'range': [0.05, 1.0]},
            'v_pd_hf_tweezer_1064_rampdown2_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown2_end, 'range': [0.09, 0.2]}
            }


            # 't_hf_tweezer_1064_rampdown3': {'initial': p.t_hf_tweezer_1064_rampdown3, 'range': [0.1, 1.0]},
            # 'v_pd_hf_tweezer_1064_rampdown3_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown3_end, 'range': [0.1, 1.5]}

# %%
# generate lists of initial values and parameter ranges to feed to MLOOP controller

init_params = [entry['initial'] for entry in var_dict.values()]
print(init_params)

ranges = [entry['range'] for entry in var_dict.values()]
print(ranges)

var_names = list(var_dict.keys())
# Out:
# [0.479, 0.536, 193.2, 0.16, 9.5, 193.6, 0.1, 1.16, 193.846, 0.566, 0.16]
# [[0.3, 2.0], [-4.0, 1.0], [190.0, 194.0], [0.02, 0.3], [4.0, 9.5], [191.0, 195.0], [0.02, 0.5], [0.3, 2.0], [192.0, 195.0], [0.05, 1.0], [0.09, 0.2]]

# %%
def main():
    #M-LOOP can be run with three commands
    
    #First create your interface
    interface = lib.CustomInterface(var_names)
    #Next create the controller. 
    #The controller must take the variables to be changed in the vars object
    #vars = Param()


    controller = lib.mlc.create_controller(interface, 
                                       controller_type = 'neural_net',  #type of controller to use, can be 'neural_network', 'gaussian process', 'differential evolution', 'random', 'nelder_mead''
                                       max_num_runs = 1500,
                                       target_cost = -109090000000,
                                       num_params = len(var_names),
                                       first_params = init_params, 
                                       min_boundary = np.transpose(ranges)[0],
                                       max_boundary = np.transpose(ranges)[1],
                                       interface_file_type = 'txt',               #file types of *exp_input.mat* and *exp_output.mat*
                                       controller_archive_file_type = 'txt',      #file type of the controller archive
                                       learner_archive_file_type = 'txt')      #file type of the learner archive
    controller.optimize()

main()
# Out:
# INFO     Optimization started.
# INFO     Run: 0 (training)
# INFO     params [4.79000e-01 5.36000e-01 1.93200e+02 1.60000e-01 9.50000e+00 1.93600e+02
#  1.00000e-01 1.16000e+00 1.93846e+02 5.66000e-01 1.60000e-01]
# 0 Run id: 55806
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55806
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55806.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -207.25471294217036
# INFO     cost -207.25471294217036 +/- 0.0
# INFO     Run: 1 (training)
# INFO     params [ 5.49105623e-01 -1.33962624e-04  1.93450250e+02  1.99596607e-01
#   8.11463476e+00  1.92193640e+02  4.51476192e-01  1.44022179e+00
#   1.92379501e+02  8.51368852e-01  1.32388425e-01]
# 0 Run id: 55807
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55807
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55807.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -103.67929185102889
# INFO     cost -103.67929185102889 +/- 0.0
# INFO     Run: 2 (training)
# INFO     params [ 4.60645095e-01 -1.43683162e+00  1.90802060e+02  2.06447265e-01
#   7.92179067e+00  1.93941341e+02  7.52462771e-02  1.37013253e+00
#   1.92397922e+02  6.32185794e-01  1.30547388e-01]
# 0 Run id: 55808
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55808
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55808.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -116.88858476766
# INFO     cost -116.88858476766 +/- 0.0
# INFO     Run: 3 (training)
# INFO     params [ 5.42439946e-01 -2.77716521e+00  1.92261723e+02  2.79044525e-01
#   8.04569795e+00  1.92336473e+02  3.72778371e-01  5.04242957e-01
#   1.94119051e+02  5.22189472e-01  1.47948675e-01]
# 0 Run id: 55809
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55809
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55809.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -174.5509316934268
# INFO     cost -174.5509316934268 +/- 0.0
# INFO     Run: 4 (training)
# INFO     params [ 1.46520043e+00 -1.21479382e+00  1.92788994e+02  1.43466297e-01
#   8.49376536e+00  1.92891061e+02  1.14327767e-01  1.52828157e+00
#   1.94311670e+02  6.86505033e-01  1.76500789e-01]
# 0 Run id: 55810
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55810
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55810.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -108.63890726904619
# INFO     cost -108.63890726904619 +/- 0.0
# INFO     Run: 5 (training)
# INFO     params [ 1.47960415e+00 -2.03148257e+00  1.91325427e+02  1.85481224e-01
#   6.52381908e+00  1.94375444e+02  1.88329636e-01  1.62689406e+00
#   1.93463934e+02  5.58632360e-01  1.85589311e-01]
# 0 Run id: 55811
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55811
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55811.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -96.5730642867362
# INFO     cost -96.5730642867362 +/- 0.0
# INFO     Run: 6 (training)
# INFO     params [1.02893066e+00 6.51782259e-01 1.92228284e+02 1.08659551e-01
#  4.84971746e+00 1.91794129e+02 1.55777886e-01 9.86730299e-01
#  1.94265198e+02 9.68018464e-01 1.40968933e-01]
# 0 Run id: 55812
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55812
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55812.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -92.13768072516991
# INFO     cost -92.13768072516991 +/- 0.0
# INFO     Run: 7 (training)
# INFO     params [5.99096025e-01 8.94726582e-01 1.93151457e+02 9.42403640e-02
#  8.75347477e+00 1.93937932e+02 1.55044092e-01 3.43357997e-01
#  1.94140322e+02 4.31248184e-01 9.75188474e-02]
# 0 Run id: 55813
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55813
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55813.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -110.73688087973022
# INFO     cost -110.73688087973022 +/- 0.0
# INFO     Run: 8 (training)
# INFO     params [ 1.44673625e+00 -3.09481833e+00  1.90650332e+02  2.92509837e-01
#   7.35680127e+00  1.91996843e+02  8.35891786e-02  1.83898556e+00
#   1.93685147e+02  2.32175254e-01  1.53091094e-01]
# 0 Run id: 55814
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55814
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55814.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -93.60740902228478
# INFO     cost -93.60740902228478 +/- 0.0
# INFO     Run: 9 (training)
# INFO     params [4.97877318e-01 4.48542169e-01 1.90943546e+02 5.11858797e-02
#  5.64125917e+00 1.91548983e+02 3.17379420e-01 5.95976007e-01
#  1.92805930e+02 9.54858743e-01 1.50520014e-01]
# 0 Run id: 55815
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55815
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55815.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -97.42563859355074
# INFO     cost -97.42563859355074 +/- 0.0
# INFO     Run: 10 (training)
# INFO     params [7.52201497e-01 8.88710785e-01 1.92926980e+02 5.20112912e-02
#  4.30314364e+00 1.92916007e+02 3.06207526e-01 1.12240684e+00
#  1.94749214e+02 5.07867402e-01 1.96154440e-01]
# 0 Run id: 55816
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55816
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55816.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -88.88004594523075
# INFO     cost -88.88004594523075 +/- 0.0
# INFO     Run: 11 (training)
# INFO     params [ 1.93378505e+00 -2.50149344e+00  1.91566210e+02  1.94732816e-01
#   5.80775068e+00  1.93183236e+02  5.62905810e-02  7.32872883e-01
#   1.94684734e+02  9.65192564e-01  1.75749830e-01]
# 0 Run id: 55817
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55817
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55817.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -92.55210764385386
# INFO     cost -92.55210764385386 +/- 0.0
# INFO     Run: 12 (training)
# INFO     params [ 1.63372299e+00 -3.45299945e+00  1.91628886e+02  1.19954655e-01
#   6.99256019e+00  1.92742619e+02  1.78990589e-01  4.63788949e-01
#   1.94216296e+02  6.54145370e-01  1.07129654e-01]
# 0 Run id: 55818
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55818
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55818.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -100.80120820644288
# INFO     cost -100.80120820644288 +/- 0.0
# INFO     Run: 13 (training)
# INFO     params [1.65434304e+00 8.53262772e-01 1.93399539e+02 1.44927695e-01
#  4.06453755e+00 1.91361601e+02 4.67730747e-01 1.34925071e+00
#  1.93523384e+02 2.83897901e-01 1.95607712e-01]
# 0 Run id: 55819
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55819
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55819.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -90.04771013869242
# INFO     cost -90.04771013869242 +/- 0.0
# INFO     Run: 14 (training)
# INFO     params [7.33002384e-01 1.12420783e-02 1.93456065e+02 2.69352184e-01
#  6.32187847e+00 1.91530023e+02 2.39406100e-02 1.61960239e+00
#  1.92532243e+02 3.83505341e-01 1.76160997e-01]
# 0 Run id: 55820
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55820
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55820.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -116.65690493046283
# INFO     cost -116.65690493046283 +/- 0.0
# INFO     Run: 15 (training)
# INFO     params [6.74199476e-01 6.89896717e-01 1.91162615e+02 1.08632060e-01
#  7.21047449e+00 1.91769040e+02 4.47802894e-01 1.40497257e+00
#  1.93116798e+02 5.38171630e-01 1.23204023e-01]
# 0 Run id: 55821
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55821
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55821.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -93.89465873079398
# INFO     cost -93.89465873079398 +/- 0.0
# INFO     Run: 16 (training)
# INFO     params [ 8.75814087e-01 -1.57239882e+00  1.93388025e+02  8.21592271e-02
#   6.53513787e+00  1.94780306e+02  1.67184678e-01  3.47459474e-01
#   1.94397394e+02  5.10311893e-01  1.12496919e-01]
# 0 Run id: 55822
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55822
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55822.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -141.4321445397797
# INFO     cost -141.4321445397797 +/- 0.0
# INFO     Run: 17 (training)
# INFO     params [ 7.99078602e-01 -1.66480316e+00  1.90920543e+02  5.59918562e-02
#   7.98641163e+00  1.92998432e+02  2.48639414e-01  7.86963334e-01
#   1.92357176e+02  9.09357770e-01  1.15418656e-01]
# 0 Run id: 55823
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55823
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55823.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -105.30872447729543
# INFO     cost -105.30872447729543 +/- 0.0
# INFO     Run: 18 (training)
# INFO     params [ 5.48222563e-01 -1.52931777e+00  1.91899202e+02  2.75354145e-01
#   9.39270393e+00  1.92397689e+02  3.96359376e-01  1.00979939e+00
#   1.93072673e+02  9.61901281e-01  1.16984779e-01]
# 0 Run id: 55824
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55824
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55824.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -134.6648594437588
# INFO     cost -134.6648594437588 +/- 0.0
# INFO     Run: 19 (training)
# INFO     params [ 1.87183958e+00 -1.19833906e+00  1.93900522e+02  2.62557628e-01
#   7.26711551e+00  1.93489035e+02  4.38236089e-02  1.11149155e+00
#   1.92275244e+02  7.84206065e-01  1.57190993e-01]
# 0 Run id: 55825
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55825
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55825.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -98.07071832866482
# INFO     cost -98.07071832866482 +/- 0.0
# INFO     Run: 20 (training)
# INFO     params [ 1.18827898e+00 -1.10274231e+00  1.91066011e+02  1.22508641e-01
#   9.13833421e+00  1.93100359e+02  2.31148734e-01  6.35490777e-01
#   1.92150144e+02  8.19903362e-01  9.45856317e-02]
# 0 Run id: 55826
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55826
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55826.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -94.2660372838456
# INFO     cost -94.2660372838456 +/- 0.0
# INFO     Run: 21 (training)
# INFO     params [1.07872889e+00 3.88501004e-01 1.92072644e+02 2.69119942e-01
#  6.40370117e+00 1.94574846e+02 3.80565953e-01 7.66419203e-01
#  1.94193305e+02 9.89594938e-01 1.93603926e-01]
# 0 Run id: 55827
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55827
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55827.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -106.54378347251277
# INFO     cost -106.54378347251277 +/- 0.0
# INFO     Run: 22 (training)
# INFO     params [ 1.15240452e+00 -2.42115860e+00  1.90334435e+02  5.20743591e-02
#   5.52255699e+00  1.92807109e+02  2.74978130e-01  3.10555528e-01
#   1.93811328e+02  4.67189353e-01  1.04572270e-01]
# 0 Run id: 55828
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55828
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55828.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -95.32873463348066
# INFO     cost -95.32873463348066 +/- 0.0
# INFO     Run: 23 (trainer)
# INFO     params [  0.86208559   0.92210559 193.88831943   0.29844835   8.96557568
#  194.96064427   0.28145785   1.22683662 194.70059337   0.7388627
#    0.1962286 ]
# 0 Run id: 55829
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55829
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55829.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -142.664360650509
# INFO     cost -142.664360650509 +/- 0.0
# INFO     Run: 24 (machine learner)
# INFO     params [5.71442384e-01 1.00000000e+00 1.94000000e+02 3.00000000e-01
#  9.50000000e+00 1.93747546e+02 2.00000000e-02 9.53772230e-01
#  1.94352234e+02 5.74133020e-01 1.47456884e-01]
# 0 Run id: 55830
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55830
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55830.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -127.18376506870364
# INFO     cost -127.18376506870364 +/- 0.0
# INFO     Run: 25 (machine learner)
# INFO     params [3.00000000e-01 1.00000000e+00 1.92062103e+02 2.65457016e-01
#  9.50000000e+00 1.95000000e+02 2.84971577e-01 1.65529564e+00
#  1.93254897e+02 5.00000000e-02 1.76684130e-01]
# 0 Run id: 55831
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55831
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55831.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -99.29653501630084
# INFO     cost -99.29653501630084 +/- 0.0
# INFO     Run: 26 (machine learner)
# INFO     params [3.00000000e-01 1.00000000e+00 1.90622721e+02 1.48808899e-01
#  9.50000000e+00 1.92078759e+02 2.30068004e-02 1.50035719e+00
#  1.95000000e+02 4.88242064e-01 9.06135461e-02]
# 0 Run id: 55832
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55832
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55832.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -95.1303213185625
# INFO     cost -95.1303213185625 +/- 0.0
# INFO     Run: 27 (trainer)
# INFO     params [ 1.62413334e+00 -9.53535571e-01  1.91345100e+02  1.16289263e-01
#   5.51132976e+00  1.91677729e+02  3.90427499e-01  3.43669987e-01
#   1.92324295e+02  2.56342613e-01  9.46347060e-02]
# 0 Run id: 55833
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55833
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55833.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -95.62490146496499
# INFO     cost -95.62490146496499 +/- 0.0
# INFO     Run: 28 (machine learner)
# INFO     params [3.00000000e-01 8.01414375e-01 1.93813353e+02 1.04991785e-01
#  9.50000000e+00 1.94196718e+02 8.04891603e-02 1.41413426e+00
#  1.93853088e+02 5.14953874e-01 1.59498501e-01]
# 0 Run id: 55834
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55834
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55834.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -102.69447270552332
# INFO     cost -102.69447270552332 +/- 0.0
# INFO     Run: 29 (machine learner)
# INFO     params [3.00000000e-01 1.00000000e+00 1.93433234e+02 1.55788026e-01
#  9.50000000e+00 1.94077475e+02 2.00000000e-02 1.41544863e+00
#  1.93882155e+02 5.82773319e-01 1.64482610e-01]
# 0 Run id: 55835
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55835
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55835.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -101.15063009169349
# INFO     cost -101.15063009169349 +/- 0.0
# INFO     Run: 30 (machine learner)
# INFO     params [3.91439857e-01 4.09064889e-01 1.94000000e+02 8.94895890e-02
#  9.50000000e+00 1.94490595e+02 7.33171431e-02 1.10243675e+00
#  1.93156179e+02 4.51735967e-01 1.79016516e-01]
# 0 Run id: 55836
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55836
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55836.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -149.81998064068304
# INFO     cost -149.81998064068304 +/- 0.0
# INFO     Run: 31 (trainer)
# INFO     params [1.79584708e+00 1.33583941e-01 1.92304522e+02 2.08712141e-01
#  7.99349973e+00 1.94460892e+02 5.24483553e-02 1.44195308e+00
#  1.92653842e+02 2.99974122e-01 1.29269793e-01]
# 0 Run id: 55837
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55837
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55837.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -96.40313717529625
# INFO     cost -96.40313717529625 +/- 0.0
# INFO     Run: 32 (machine learner)
# INFO     params [5.26906415e-01 8.19641408e-01 1.92949375e+02 1.56630099e-01
#  9.50000000e+00 1.93226073e+02 1.14551201e-01 8.37548230e-01
#  1.93716424e+02 6.26128486e-01 1.57512337e-01]
# 0 Run id: 55838
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55838
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55838.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -160.24810747298892
# INFO     cost -160.24810747298892 +/- 0.0
# INFO     Run: 33 (machine learner)
# INFO     params [5.27195812e-01 1.00000000e+00 1.93044756e+02 1.49951744e-01
#  9.50000000e+00 1.93447483e+02 8.32287623e-02 1.12620937e+00
#  1.93677268e+02 5.49012947e-01 1.64568286e-01]
# 0 Run id: 55839
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55839
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55839.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -147.7103002101119
# INFO     cost -147.7103002101119 +/- 0.0
# INFO     Run: 34 (machine learner)
# INFO     params [ 3.00000000e-01 -1.35235229e-01  1.94000000e+02  1.79178465e-01
#   9.50000000e+00  1.93566078e+02  1.58182307e-01  1.09332007e+00
#   1.93628483e+02  5.85228560e-01  1.76434172e-01]
# 0 Run id: 55840
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55840
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55840.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -102.53305368259545
# INFO     cost -102.53305368259545 +/- 0.0
# INFO     Run: 35 (trainer)
# INFO     params [  0.57999277  -0.91050956 191.37474885   0.21724323   6.57462669
#  194.46236839   0.22848337   0.56662211 192.00586964   0.82972644
#    0.19534305]
# 0 Run id: 55841
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55841
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55841.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -141.16880543973875
# INFO     cost -141.16880543973875 +/- 0.0
# INFO     Run: 36 (machine learner)
# INFO     params [ 4.88911183e-01 -6.21866263e-02  1.93276682e+02  1.89524841e-01
#   9.50000000e+00  1.93761020e+02  9.99211877e-02  1.23355105e+00
#   1.94069484e+02  6.15734268e-01  1.46943539e-01]
# 0 Run id: 55842
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55842
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55842.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -246.43693588879043
# INFO     cost -246.43693588879043 +/- 0.0
# INFO     Run: 37 (machine learner)
# INFO     params [4.32863398e-01 3.13301262e-01 1.92995489e+02 1.66502942e-01
#  9.50000000e+00 1.93931236e+02 1.26089395e-01 1.19032991e+00
#  1.93842798e+02 5.59929528e-01 1.56778429e-01]
# 0 Run id: 55843
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55843
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55843.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -225.17910177904355
# INFO     cost -225.17910177904355 +/- 0.0
# INFO     Run: 38 (machine learner)
# INFO     params [ 6.60815572e-01 -6.75922792e-01  1.92718388e+02  1.67374157e-01
#   9.50000000e+00  1.93897411e+02  1.41116271e-01  1.33046261e+00
#   1.94391596e+02  4.81253362e-01  1.51454978e-01]
# 0 Run id: 55844
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55844
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55844.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -245.28168517714616
# INFO     cost -245.28168517714616 +/- 0.0
# INFO     Run: 39 (trainer)
# INFO     params [ 1.55960504e+00 -7.13828251e-01  1.92130204e+02  2.34537673e-02
#   5.92467647e+00  1.91607626e+02  2.29418236e-02  1.80698625e+00
#   1.93031327e+02  5.42738840e-01  1.18564667e-01]
# 0 Run id: 55845
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55845
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55845.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -87.90431048636559
# INFO     cost -87.90431048636559 +/- 0.0
# INFO     Run: 40 (machine learner)
# INFO     params [ 6.02179006e-01 -5.76223074e-01  1.93286281e+02  1.91794941e-01
#   9.50000000e+00  1.93809927e+02  1.30729397e-01  1.37191414e+00
#   1.94346706e+02  5.85356035e-01  1.38568672e-01]
# 0 Run id: 55846
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55846
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55846.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -248.09747034072848
# INFO     cost -248.09747034072848 +/- 0.0
# INFO     Run: 41 (machine learner)
# INFO     params [ 6.04959919e-01 -7.56814913e-01  1.93043556e+02  1.87489783e-01
#   9.50000000e+00  1.94226589e+02  1.05626274e-01  1.32327431e+00
#   1.94345187e+02  6.01388848e-01  1.47345966e-01]
# 0 Run id: 55847
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55847
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55847.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -244.27245410828752
# INFO     cost -244.27245410828752 +/- 0.0
# INFO     Run: 42 (machine learner)
# INFO     params [ 5.31866118e-01 -9.56304479e-01  1.93173090e+02  1.79626840e-01
#   9.50000000e+00  1.94039630e+02  1.44789118e-01  1.32652485e+00
#   1.94362338e+02  5.41921691e-01  1.44483337e-01]
# 0 Run id: 55848
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55848
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55848.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -261.14464552834625
# INFO     cost -261.14464552834625 +/- 0.0
# INFO     Run: 43 (trainer)
# INFO     params [ 6.61794191e-01 -2.53173781e-01  1.91829173e+02  1.34643672e-01
#   7.50173519e+00  1.92958650e+02  1.43145737e-01  8.11220896e-01
#   1.94773040e+02  4.13373256e-01  1.36549003e-01]
# 0 Run id: 55849
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55849
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55849.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -126.90649299298724
# INFO     cost -126.90649299298724 +/- 0.0
# INFO     Run: 44 (machine learner)
# INFO     params [ 4.58952162e-01 -7.51235969e-01  1.93170463e+02  1.79429603e-01
#   9.50000000e+00  1.93813748e+02  1.54230141e-01  1.24649785e+00
#   1.94323788e+02  5.03296322e-01  1.48555024e-01]
# 0 Run id: 55850
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55850
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55850.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -264.3773030183691
# INFO     cost -264.3773030183691 +/- 0.0
# INFO     Run: 45 (machine learner)
# INFO     params [ 3.00000000e-01 -1.90891013e+00  1.93304952e+02  1.84357801e-01
#   9.50000000e+00  1.94463993e+02  1.04096923e-01  1.27287745e+00
#   1.94411905e+02  5.65118217e-01  1.47044322e-01]
# 0 Run id: 55851
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55851
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55851.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -125.42475497637047
# INFO     cost -125.42475497637047 +/- 0.0
# INFO     Run: 46 (machine learner)
# INFO     params [ 5.16762818e-01 -9.87185298e-01  1.93157276e+02  1.79174718e-01
#   9.50000000e+00  1.94028808e+02  1.46964341e-01  1.31094077e+00
#   1.94344291e+02  5.28285935e-01  1.45183271e-01]
# 0 Run id: 55852
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55852
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55852.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -275.02562064831733
# INFO     cost -275.02562064831733 +/- 0.0
# INFO     Run: 47 (trainer)
# INFO     params [ 6.52766101e-01 -2.14550027e-01  1.91458484e+02  2.53216713e-01
#   4.01219744e+00  1.92834860e+02  1.25855360e-01  1.90238219e+00
#   1.93457329e+02  7.13137387e-01  1.24760368e-01]
# 0 Run id: 55853
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55853
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55853.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -90.44153151055063
# INFO     cost -90.44153151055063 +/- 0.0
# INFO     Run: 48 (machine learner)
# INFO     params [ 5.22535338e-01 -7.98511367e-01  1.93263996e+02  1.66891349e-01
#   9.50000000e+00  1.93983033e+02  1.95247832e-01  1.43043662e+00
#   1.94195723e+02  4.95203917e-01  1.49550995e-01]
# 0 Run id: 55854
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55854
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55854.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -285.8108023619038
# INFO     cost -285.8108023619038 +/- 0.0
# INFO     Run: 49 (machine learner)
# INFO     params [ 5.44828046e-01 -8.93598333e-01  1.93143614e+02  2.07567794e-01
#   9.50000000e+00  1.93912163e+02  1.58481379e-01  1.37303551e+00
#   1.94577207e+02  4.80613515e-01  1.47333018e-01]
# 0 Run id: 55855
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55855
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55855.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -211.04806656185463
# INFO     cost -211.04806656185463 +/- 0.0
# INFO     Run: 50 (machine learner)
# INFO     params [ 4.92025629e-01 -1.14774805e+00  1.93371535e+02  1.86320102e-01
#   9.50000000e+00  1.94359690e+02  1.87195028e-01  1.34622112e+00
#   1.94279621e+02  4.34281084e-01  1.41621718e-01]
# 0 Run id: 55856
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55856
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55856.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -225.86361051326938
# INFO     cost -225.86361051326938 +/- 0.0
# INFO     Run: 51 (trainer)
# INFO     params [8.58821985e-01 5.34975104e-01 1.92821020e+02 2.07360868e-01
#  8.59136393e+00 1.91238857e+02 3.73150882e-01 6.57091726e-01
#  1.93372235e+02 5.80594718e-01 1.36436953e-01]
# 0 Run id: 55857
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55857
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55857.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -103.24538204457328
# INFO     cost -103.24538204457328 +/- 0.0
# INFO     Run: 52 (machine learner)
# INFO     params [ 5.29471411e-01 -7.03353898e-01  1.93256730e+02  1.37346016e-01
#   9.50000000e+00  1.93741368e+02  2.25512077e-01  1.47878118e+00
#   1.94061180e+02  4.88437739e-01  1.55878400e-01]
# 0 Run id: 55858
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55858
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55858.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -264.919804112759
# INFO     cost -264.919804112759 +/- 0.0
# INFO     Run: 53 (machine learner)
# INFO     params [ 3.61527236e-01 -9.87848400e-01  1.92874689e+02  1.11914658e-01
#   9.50000000e+00  1.94639959e+02  3.43817360e-01  1.74436389e+00
#   1.94398896e+02  3.99948034e-01  1.64755582e-01]
# 0 Run id: 55859
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55859
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55859.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -146.94535064636526
# INFO     cost -146.94535064636526 +/- 0.0
# INFO     Run: 54 (machine learner)
# INFO     params [ 5.45009179e-01 -1.01419503e+00  1.93091609e+02  1.31574512e-01
#   9.50000000e+00  1.93823506e+02  2.55610573e-01  1.45836930e+00
#   1.94274824e+02  5.29978847e-01  1.52574487e-01]
# 0 Run id: 55860
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55860
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55860.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -245.1588549063379
# INFO     cost -245.1588549063379 +/- 0.0
# INFO     Run: 55 (trainer)
# INFO     params [9.38410867e-01 1.89809941e-01 1.92831136e+02 2.60963867e-01
#  8.84406979e+00 1.92687535e+02 2.06614672e-01 9.39735268e-01
#  1.93949007e+02 9.25833570e-01 1.51841628e-01]
# 0 Run id: 55861
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55861
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55861.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -118.98014110674029
# INFO     cost -118.98014110674029 +/- 0.0
# INFO     Run: 56 (machine learner)
# INFO     params [ 5.65652072e-01 -6.63305926e-01  1.93358863e+02  1.60048498e-01
#   9.50000000e+00  1.93953060e+02  1.82308470e-01  1.36249597e+00
#   1.93982529e+02  5.09017690e-01  1.49425328e-01]
# 0 Run id: 55862
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55862
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55862.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -268.03670891030583
# INFO     cost -268.03670891030583 +/- 0.0
# INFO     Run: 57 (machine learner)
# INFO     params [ 4.18159774e-01 -1.06205544e+00  1.93385852e+02  1.54894760e-01
#   9.50000000e+00  1.93808648e+02  1.70377212e-01  1.33531528e+00
#   1.94029758e+02  4.71535983e-01  1.43991974e-01]
# 0 Run id: 55863
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# ...
# 0 Run id: 56297
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56297
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56297.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -93.63183784554212
# INFO     cost -93.63183784554212 +/- 0.0
# INFO     Run: 492 (machine learner)
# INFO     params [ 6.06459114e-01 -9.00668201e-01  1.93099278e+02  1.65668918e-01
#   9.50000000e+00  1.94036889e+02  1.74491203e-01  1.29698796e+00
#   1.93971407e+02  5.61189630e-01  1.43377947e-01]
# 0 Run id: 56298
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56298
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56298.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -244.73701398827427
# INFO     cost -244.73701398827427 +/- 0.0
# INFO     Run: 493 (machine learner)
# INFO     params [ 3.00000000e-01 -1.50350192e+00  1.92336477e+02  8.59084720e-02
#   9.50000000e+00  1.92597883e+02  2.06421401e-01  1.38568699e+00
#   1.93068964e+02  6.77501794e-01  1.45187351e-01]
# 0 Run id: 56299
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56299
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56299.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -101.67428876963113
# INFO     cost -101.67428876963113 +/- 0.0
# INFO     Run: 494 (machine learner)
# INFO     params [ 5.92986438e-01 -9.36372893e-01  1.93068168e+02  1.66615828e-01
#   9.50000000e+00  1.94081149e+02  1.69434861e-01  1.29936655e+00
#   1.93975260e+02  5.57269333e-01  1.42985018e-01]
# 0 Run id: 56300
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56300
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56300.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -246.95792736861452
# INFO     cost -246.95792736861452 +/- 0.0
# INFO     Run: 495 (trainer)
# INFO     params [ 1.45748759e+00 -8.30184007e-01  1.92426698e+02  1.66150571e-01
#   7.11704574e+00  1.93746013e+02  2.14382855e-01  9.42981271e-01
#   1.92113784e+02  5.82637709e-01  1.49111968e-01]
# 0 Run id: 56301
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56301
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56301.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -89.97114966935094
# INFO     cost -89.97114966935094 +/- 0.0
# INFO     Run: 496 (machine learner)
# INFO     params [ 5.94893661e-01 -9.02704158e-01  1.93132085e+02  1.66846188e-01
#   9.50000000e+00  1.94099979e+02  1.81935168e-01  1.29171717e+00
#   1.93917800e+02  5.59186236e-01  1.43849542e-01]
# 0 Run id: 56302
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56302
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56302.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -252.00924210746965
# INFO     cost -252.00924210746965 +/- 0.0
# INFO     Run: 497 (machine learner)
# INFO     params [ 1.84757964e+00 -3.06564400e+00  1.94000000e+02  3.00000000e-01
#   9.50000000e+00  1.93492158e+02  4.71014723e-02  3.00000000e-01
#   1.94898018e+02  5.12407093e-01  2.00000000e-01]
# 0 Run id: 56303
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56303
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56303.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -94.81986923507601
# INFO     cost -94.81986923507601 +/- 0.0
# INFO     Run: 498 (machine learner)
# INFO     params [ 5.93813861e-01 -9.36795243e-01  1.93081455e+02  1.66593517e-01
#   9.50000000e+00  1.94120342e+02  1.72380775e-01  1.30268931e+00
#   1.93963538e+02  5.59737435e-01  1.43035550e-01]
# 0 Run id: 56304
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56304
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56304.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -307.80776983248666
# INFO     cost -307.80776983248666 +/- 0.0
# INFO     Run: 499 (trainer)
# INFO     params [ 1.20581072e+00 -1.27302146e-01  1.91227090e+02  1.55845823e-01
#   4.96349931e+00  1.94488705e+02  3.08329589e-01  1.66411079e+00
#   1.92225432e+02  8.84960519e-01  1.58284671e-01]
# 0 Run id: 56305
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56305
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56305.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -92.87068972165368
# INFO     cost -92.87068972165368 +/- 0.0
# INFO     Run: 500 (machine learner)
# INFO     params [ 5.96791582e-01 -9.43658003e-01  1.93079707e+02  1.66683349e-01
#   9.50000000e+00  1.94101702e+02  1.70965910e-01  1.30031821e+00
#   1.93967033e+02  5.60124904e-01  1.43183840e-01]
# 0 Run id: 56306
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56306
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56306.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -288.101371105704
# INFO     cost -288.101371105704 +/- 0.0
# INFO     Run: 501 (machine learner)
# INFO     params [ 5.94769123e-01 -9.48777633e-01  1.93110152e+02  1.66052726e-01
#   9.49781446e+00  1.94104475e+02  1.71781560e-01  1.30158770e+00
#   1.93968432e+02  5.64568971e-01  1.43338901e-01]
# 0 Run id: 56307
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56307
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56307.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -257.8604710694417
# INFO     cost -257.8604710694417 +/- 0.0
# INFO     Run: 502 (machine learner)
# INFO     params [ 7.72807030e-01 -5.96827702e-01  1.92805171e+02  1.56495256e-01
#   8.48422792e+00  1.93108212e+02  1.64248723e-01  1.07896802e+00
#   1.93723523e+02  5.87344286e-01  1.42673414e-01]
# 0 Run id: 56308
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56308
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56308.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -156.0440046997845
# INFO     cost -156.0440046997845 +/- 0.0
# INFO     Run: 503 (trainer)
# INFO     params [1.94463255e+00 4.00301754e-01 1.91115749e+02 2.40633556e-01
#  7.03526141e+00 1.91879333e+02 4.19737791e-02 5.91988875e-01
#  1.92051001e+02 7.78025649e-01 1.40623180e-01]
# 0 Run id: 56309
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56309
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56309.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -92.23980800337688
# INFO     cost -92.23980800337688 +/- 0.0
# INFO     Run: 504 (machine learner)
# INFO     params [ 6.04600180e-01 -9.56435290e-01  1.93080799e+02  1.66061859e-01
#   9.49905748e+00  1.94134408e+02  1.75164900e-01  1.29166651e+00
#   1.93980041e+02  5.50769519e-01  1.43606621e-01]
# 0 Run id: 56310
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56310
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56310.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -289.72498019362206
# INFO     cost -289.72498019362206 +/- 0.0
# INFO     Run: 505 (machine learner)
# INFO     params [ 6.04098463e-01 -9.26634569e-01  1.93094143e+02  1.66830238e-01
#   9.49811937e+00  1.94086727e+02  1.74080933e-01  1.30147578e+00
#   1.93960642e+02  5.56583755e-01  1.43203348e-01]
# 0 Run id: 56311
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56311
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56311.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -275.9494161282499
# INFO     cost -275.9494161282499 +/- 0.0
# INFO     Run: 506 (machine learner)
# INFO     params [ 6.28677789e-01 -9.66203414e-01  1.93075162e+02  1.64538803e-01
#   9.28937205e+00  1.93966958e+02  1.72366238e-01  1.29277326e+00
#   1.93894532e+02  5.61103946e-01  1.44095539e-01]
# 0 Run id: 56312
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56312
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56312.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -281.4995393416007
# INFO     cost -281.4995393416007 +/- 0.0
# INFO     Run: 507 (trainer)
# INFO     params [1.18641419e+00 2.55719483e-01 1.93395020e+02 2.24875525e-01
#  6.71251168e+00 1.94540107e+02 3.75508946e-01 1.84500093e+00
#  1.94592680e+02 6.60973827e-01 1.11109779e-01]
# 0 Run id: 56313
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56313
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56313.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -89.85690484861556
# INFO     cost -89.85690484861556 +/- 0.0
# INFO     Run: 508 (machine learner)
# INFO     params [ 3.00000000e-01 -1.62915428e+00  1.93984232e+02  1.74402095e-01
#   9.50000000e+00  1.94163324e+02  4.21550601e-01  1.59314727e+00
#   1.95000000e+02  4.21083230e-01  1.35653273e-01]
# 0 Run id: 56314
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56314
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56314.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -118.43509158123601
# INFO     cost -118.43509158123601 +/- 0.0
# INFO     Run: 509 (machine learner)
# INFO     params [ 6.37534316e-01 -1.62896519e-01  1.93455106e+02  1.71056415e-01
#   9.50000000e+00  1.95000000e+02  1.40699568e-01  1.45912999e+00
#   1.94336756e+02  5.57932591e-01  1.39595047e-01]
# 0 Run id: 56315
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 56315
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 56315.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 55799.
# Using ROI loaded from run 55799.
# -134.38008992407762
# INFO     cost -134.38008992407762 +/- 0.0
# INFO     Run: 510 (machine learner)
# INFO     params [ 5.89812217e-01 -9.74445046e-01  1.93070915e+02  1.65613915e-01
#   9.47871365e+00  1.94069669e+02  1.66741868e-01  1.31998478e+00
#   1.93925162e+02  5.52052777e-01  1.43474028e-01]

# %%
#### uncomment this and run it if u wanna delete the logs


# import os, shutil
# # Specify the path of the file to be deleted
# folder = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_archives'
# file_path_2 = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_logs'

# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))

# for filename in os.listdir(file_path_2):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))
