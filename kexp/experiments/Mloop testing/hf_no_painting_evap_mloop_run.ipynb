# %%
# import vars 
import integration.hf_no_painting_exp as lib
import os
import numpy as np

from kexp.config import ExptParams

p = ExptParams()

# %%
var_dict = {'v_pd_hf_lightsheet_rampdown_end': {'initial': p.v_pd_hf_lightsheet_rampdown_end, 'range': [.3, 2.0]},
            'v_hf_tweezer_paint_amp_max': {'initial': p.v_hf_tweezer_paint_amp_max, 'range': [-4.0, 1.0]},
            'i_hf_tweezer_load_current': {'initial': p.i_hf_tweezer_load_current, 'range': [190.0, 194.0]},
            't_hf_tweezer_1064_ramp': {'initial': p.t_hf_tweezer_1064_ramp, 'range': [0.02, 0.5]},
            'v_pd_hf_tweezer_1064_ramp_end': {'initial': p.v_pd_hf_tweezer_1064_ramp_end, 'range': [4.0, 9.5]},
            'i_hf_tweezer_evap1_current': {'initial': p.i_hf_tweezer_evap1_current, 'range': [191.0, 195.0]},
            't_hf_tweezer_1064_rampdown': {'initial': p.t_hf_tweezer_1064_rampdown, 'range': [0.02, 0.5]},
            'v_pd_hf_tweezer_1064_rampdown_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown_end, 'range': [0.3, 3.0]},
            'i_hf_tweezer_evap2_current': {'initial': p.i_hf_tweezer_evap2_current, 'range': [192.0, 195.0]},
            't_hf_tweezer_1064_rampdown2': {'initial': p.t_hf_tweezer_1064_rampdown2, 'range': [0.05, 1.0]},
            'v_pd_hf_tweezer_1064_rampdown2_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown2_end, 'range': [0.07, 0.13]},
            't_hf_tweezer_1064_rampdown3': {'initial': p.t_hf_tweezer_1064_rampdown3, 'range': [0.1, 1.0]},
            'v_pd_hf_tweezer_1064_rampdown3_end': {'initial': p.v_pd_hf_tweezer_1064_rampdown3_end, 'range': [0.1, 1.5]}
            }

# %%
# generate lists of initial values and parameter ranges to feed to MLOOP controller

init_params = [entry['initial'] for entry in var_dict.values()]
print(init_params)

ranges = [entry['range'] for entry in var_dict.values()]
print(ranges)

var_names = list(var_dict.keys())
# Out:
# [192.8, 194.0, 192.7, 0.1, 0.25, -1.5, 9.5, 0.1, 1.2, 0.5, 0.5]
# [[191.0, 195.0], [192.0, 195.0], [190.0, 195.0], [0.02, 0.5], [0.05, 1.0], [-4.0, 1.0], [4.0, 9.5], [0.07, 0.13], [0.3, 3.0], [0.1, 1.5], [0.1, 1.0]]

# %%
def main():
    #M-LOOP can be run with three commands
    
    #First create your interface
    interface = lib.CustomInterface(var_names)
    #Next create the controller. 
    #The controller must take the variables to be changed in the vars object
    #vars = Param()


    controller = lib.mlc.create_controller(interface, 
                                       controller_type = 'neural_net',  #type of controller to use, can be 'neural_network', 'gaussian process', 'differential evolution', 'random', 'nelder_mead''
                                       max_num_runs = 1180,
                                       target_cost = -109090000000,
                                       num_params = len(var_names),
                                       first_params = init_params, 
                                       min_boundary = np.transpose(ranges)[0],
                                       max_boundary = np.transpose(ranges)[1],
                                       interface_file_type = 'txt',               #file types of *exp_input.mat* and *exp_output.mat*
                                       controller_archive_file_type = 'txt',      #file type of the controller archive
                                       learner_archive_file_type = 'txt')      #file type of the learner archive
    controller.optimize()

main()
# Out:
# INFO     M-LOOP version 3.3.5
# INFO     Optimization started.
# INFO     Run: 0 (training)
# INFO     params [ 1.928e+02  1.940e+02  1.927e+02  1.000e-01  2.500e-01 -1.500e+00
#   9.500e+00  1.000e-01  1.200e+00  5.000e-01  5.000e-01]
# 0 Run id: 54515
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54515
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54515.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -87.38511678212808
# INFO     cost -87.38511678212808 +/- 0.0
# INFO     Run: 1 (training)
# INFO     params [ 1.93626760e+02  1.93505683e+02  1.93098951e+02  2.06174122e-01
#   5.76404609e-01 -2.85526688e+00  4.39232307e+00  1.05054751e-01
#   8.25981361e-01  2.88736362e-01  4.38874633e-01]
# 0 Run id: 54516
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54516
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54516.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -42.833397879841066
# INFO     cost -42.833397879841066 +/- 0.0
# INFO     Run: 2 (training)
# INFO     params [1.94974327e+02 1.92494486e+02 1.93801777e+02 4.44699107e-01
#  7.16137761e-01 5.34401754e-01 6.90073072e+00 9.28101216e-02
#  2.11334845e+00 1.48434528e+00 4.36862472e-01]
# 0 Run id: 54517
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54517
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54517.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.249229184916565
# INFO     cost -41.249229184916565 +/- 0.0
# INFO     Run: 3 (training)
# INFO     params [ 1.91892193e+02  1.92510910e+02  1.90330160e+02  3.43284309e-01
#   3.43217398e-01 -1.28441933e+00  9.28876462e+00  8.88480658e-02
#   2.66697342e+00  3.33966574e-01  7.06490708e-01]
# 0 Run id: 54518
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54518
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54518.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.68042872217709
# INFO     cost -41.68042872217709 +/- 0.0
# INFO     Run: 4 (training)
# INFO     params [1.93973797e+02 1.92463743e+02 1.91663027e+02 4.01077281e-01
#  4.99806469e-01 4.33402736e-02 6.96181944e+00 1.26399595e-01
#  2.98403902e+00 4.45128527e-01 1.12887795e-01]
# 0 Run id: 54519
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54519
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54519.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.78008509985367
# INFO     cost -41.78008509985367 +/- 0.0
# INFO     Run: 5 (training)
# INFO     params [ 1.93792078e+02  1.92351913e+02  1.94700674e+02  3.80434795e-01
#   8.15376056e-01 -2.14836451e+00  4.97751726e+00  8.44633059e-02
#   2.37386100e+00  1.06848152e+00  3.35841723e-01]
# 0 Run id: 54520
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54520
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54520.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.07535596839951
# INFO     cost -40.07535596839951 +/- 0.0
# INFO     Run: 6 (training)
# INFO     params [ 1.93337613e+02  1.94657660e+02  1.92049281e+02  4.51733531e-01
#   7.00569440e-01 -3.60812662e+00  5.09677296e+00  7.35531338e-02
#   3.81879889e-01  1.39166418e+00  7.40041620e-01]
# 0 Run id: 54521
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54521
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54521.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -49.13000375215157
# INFO     cost -49.13000375215157 +/- 0.0
# INFO     Run: 7 (training)
# INFO     params [ 1.94213758e+02  1.93303748e+02  1.93900806e+02  3.87222996e-01
#   4.62500713e-01 -1.21593920e+00  6.10532212e+00  1.23863112e-01
#   1.48108414e+00  6.07097306e-01  4.21235494e-01]
# 0 Run id: 54522
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54522
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54522.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -46.67008648589111
# INFO     cost -46.67008648589111 +/- 0.0
# INFO     Run: 8 (training)
# INFO     params [ 1.92878917e+02  1.93200986e+02  1.92229207e+02  8.58331069e-02
#   9.91034326e-01 -8.22304125e-01  4.72623144e+00  8.21547204e-02
#   2.98361500e+00  1.15478277e+00  6.45095848e-01]
# 0 Run id: 54523
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54523
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54523.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -45.945488162067484
# INFO     cost -45.945488162067484 +/- 0.0
# INFO     Run: 9 (training)
# INFO     params [ 1.93555658e+02  1.92841646e+02  1.94498343e+02  2.53238691e-01
#   8.25907073e-01 -1.23495917e-01  4.32267409e+00  8.01269207e-02
#   1.64704630e+00  1.11525471e+00  1.99794898e-01]
# 0 Run id: 54524
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54524
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54524.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -45.17087801612765
# INFO     cost -45.17087801612765 +/- 0.0
# INFO     Run: 10 (training)
# INFO     params [1.94431322e+02 1.93856029e+02 1.90073697e+02 2.44314107e-01
#  8.72242633e-01 4.80690037e-01 7.44045531e+00 9.56499121e-02
#  2.20351047e+00 9.95349195e-01 1.41431473e-01]
# 0 Run id: 54525
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54525
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54525.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -51.923411985441966
# INFO     cost -51.923411985441966 +/- 0.0
# INFO     Run: 11 (training)
# INFO     params [ 1.93540696e+02  1.94003094e+02  1.92010975e+02  4.21323293e-01
#   3.64523267e-01 -1.27768068e+00  7.08481348e+00  1.18359884e-01
#   1.95166076e+00  2.06059991e-01  6.01510111e-01]
# 0 Run id: 54526
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54526
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54526.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.83463441727279
# INFO     cost -41.83463441727279 +/- 0.0
# INFO     Run: 12 (training)
# INFO     params [ 1.94564768e+02  1.92299555e+02  1.91850221e+02  1.06881415e-01
#   6.75926692e-01 -2.96670294e+00  8.39936797e+00  1.18108305e-01
#   4.05926063e-01  8.54449844e-01  5.02030421e-01]
# 0 Run id: 54527
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54527
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54527.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -52.13260203817106
# INFO     cost -52.13260203817106 +/- 0.0
# INFO     Run: 13 (training)
# INFO     params [ 1.91282315e+02  1.93360182e+02  1.91299320e+02  1.71297209e-01
#   6.32424427e-01 -9.30051734e-01  8.11703999e+00  1.10349886e-01
#   1.89982219e+00  3.04191337e-01  5.41924055e-01]
# 0 Run id: 54528
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54528
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54528.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -44.70173305455148
# INFO     cost -44.70173305455148 +/- 0.0
# INFO     Run: 14 (training)
# INFO     params [ 1.91407662e+02  1.93724821e+02  1.94879700e+02  2.92451946e-01
#   2.10227494e-01 -4.20743463e-01  7.07297442e+00  7.50572987e-02
#   1.87764862e+00  8.31649874e-01  4.98170664e-01]
# 0 Run id: 54529
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54529
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54529.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.85307562336723
# INFO     cost -40.85307562336723 +/- 0.0
# INFO     Run: 15 (training)
# INFO     params [ 1.94036447e+02  1.93827485e+02  1.91945437e+02  2.75921847e-01
#   8.68910431e-02 -9.18590351e-01  6.75210345e+00  8.82675274e-02
#   1.39663476e+00  1.41142160e+00  7.24545171e-01]
# 0 Run id: 54530
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54530
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54530.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -63.50523117187395
# INFO     cost -63.50523117187395 +/- 0.0
# INFO     Run: 16 (training)
# INFO     params [ 1.94245620e+02  1.94434940e+02  1.93708020e+02  2.32320027e-01
#   9.87790610e-01 -8.30800174e-01  7.69382663e+00  1.10067482e-01
#   1.64002411e+00  9.15352966e-01  6.02638349e-01]
# 0 Run id: 54531
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54531
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54531.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -48.991932185438905
# INFO     cost -48.991932185438905 +/- 0.0
# INFO     Run: 17 (training)
# INFO     params [1.94705749e+02 1.92056628e+02 1.94864629e+02 1.59885234e-01
#  6.22678529e-01 3.37941774e-01 7.85739544e+00 9.80177835e-02
#  2.26568050e+00 1.26204990e-01 1.04093178e-01]
# 0 Run id: 54532
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54532
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54532.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -39.03833738275755
# INFO     cost -39.03833738275755 +/- 0.0
# INFO     Run: 18 (training)
# INFO     params [ 1.91841180e+02  1.93947149e+02  1.93904390e+02  4.39667918e-01
#   8.01760281e-01 -2.30538319e+00  8.63034022e+00  7.84738242e-02
#   5.47334448e-01  2.08951710e-01  8.90608494e-01]
# 0 Run id: 54533
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54533
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54533.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -46.15915816996872
# INFO     cost -46.15915816996872 +/- 0.0
# INFO     Run: 19 (training)
# INFO     params [ 1.91956644e+02  1.93043373e+02  1.92260565e+02  1.61804169e-01
#   6.19483911e-01 -2.16695544e+00  6.84967243e+00  1.29281889e-01
#   1.19932886e+00  4.07182881e-01  8.86375029e-01]
# 0 Run id: 54534
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54534
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54534.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -45.733261497490325
# INFO     cost -45.733261497490325 +/- 0.0
# INFO     Run: 20 (training)
# INFO     params [ 1.93088413e+02  1.94830813e+02  1.94049591e+02  2.83431503e-01
#   5.80423811e-01 -1.06471717e+00  7.12712466e+00  1.10190112e-01
#   1.43309672e+00  3.94226383e-01  1.58622679e-01]
# 0 Run id: 54535
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54535
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54535.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -43.59381209085032
# INFO     cost -43.59381209085032 +/- 0.0
# INFO     Run: 21 (training)
# INFO     params [ 1.93776121e+02  1.94452706e+02  1.94333201e+02  4.43278498e-01
#   4.21456814e-01 -1.69705541e+00  7.95957855e+00  8.81916782e-02
#   1.97542995e+00  1.17507530e+00  9.84551551e-01]
# 0 Run id: 54536
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54536
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54536.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -50.16477354606983
# INFO     cost -50.16477354606983 +/- 0.0
# INFO     Run: 22 (training)
# INFO     params [ 1.94221968e+02  1.92937964e+02  1.94090026e+02  4.76314913e-01
#   6.69026088e-01 -1.48021792e+00  6.78283137e+00  7.13212774e-02
#   9.74445979e-01  1.19034658e+00  8.96395033e-01]
# 0 Run id: 54537
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54537
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54537.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -46.93763750961906
# INFO     cost -46.93763750961906 +/- 0.0
# INFO     Run: 23 (trainer)
# INFO     params [1.94154190e+02 1.92351291e+02 1.94367423e+02 4.46817828e-01
#  3.00532006e-01 8.28430916e-01 6.19173435e+00 1.03460416e-01
#  2.46761719e+00 1.41313823e-01 5.17522601e-01]
# 0 Run id: 54538
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54538
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54538.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.579969434745
# INFO     cost -40.579969434745 +/- 0.0
# INFO     Run: 24 (machine learner)
# INFO     params [ 1.93421454e+02  1.95000000e+02  1.90000000e+02  2.00000000e-02
#   5.00000000e-02 -2.33453485e+00  9.50000000e+00  1.30000000e-01
#   3.00000000e+00  5.56329192e-01  8.28886153e-01]
# 0 Run id: 54539
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54539
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54539.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -43.21055916386765
# INFO     cost -43.21055916386765 +/- 0.0
# INFO     Run: 25 (machine learner)
# INFO     params [ 1.91901259e+02  1.95000000e+02  1.94182508e+02  2.00000000e-02
#   5.00000000e-02 -1.98336876e+00  9.50000000e+00  1.00672737e-01
#   4.65179231e-01  1.00000000e-01  5.56590142e-01]
# 0 Run id: 54540
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54540
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54540.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -39.17144388455592
# INFO     cost -39.17144388455592 +/- 0.0
# INFO     Run: 26 (machine learner)
# INFO     params [ 1.91000000e+02  1.95000000e+02  1.90000000e+02  2.00000000e-02
#   5.00000000e-02 -4.00000000e+00  9.50000000e+00  1.05979503e-01
#   3.00000000e+00  1.38813630e-01  2.30673024e-01]
# 0 Run id: 54541
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54541
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54541.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.17011802579902
# INFO     cost -41.17011802579902 +/- 0.0
# INFO     Run: 27 (trainer)
# INFO     params [ 1.92292822e+02  1.93040046e+02  1.93632187e+02  3.44375673e-01
#   3.87328612e-01 -3.42851739e+00  7.22938290e+00  8.17051455e-02
#   2.76116935e+00  1.49322497e+00  3.34378663e-01]
# 0 Run id: 54542
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54542
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54542.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -48.60442926506636
# INFO     cost -48.60442926506636 +/- 0.0
# INFO     Run: 28 (machine learner)
# INFO     params [ 1.93313482e+02  1.93196254e+02  1.90824285e+02  2.00000000e-02
#   5.00000000e-02 -1.52915579e+00  9.50000000e+00  7.18051295e-02
#   3.00000000e-01  5.81069145e-01  4.35240754e-01]
# 0 Run id: 54543
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54543
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54543.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.60384794725284
# INFO     cost -40.60384794725284 +/- 0.0
# INFO     Run: 29 (machine learner)
# INFO     params [ 1.93002551e+02  1.93812399e+02  1.92578182e+02  1.17340553e-01
#   1.63577365e-01 -1.32834124e+00  9.50000000e+00  9.52299358e-02
#   1.59086941e+00  4.06861060e-01  5.10517993e-01]
# 0 Run id: 54544
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54544
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54544.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -67.12990220362707
# INFO     cost -67.12990220362707 +/- 0.0
# INFO     Run: 30 (machine learner)
# INFO     params [ 1.93503424e+02  1.94521800e+02  1.92926708e+02  2.00000000e-02
#   3.55462840e-01 -1.78564555e+00  9.50000000e+00  1.07410993e-01
#   1.41236814e+00  8.01090690e-01  4.58979331e-01]
# 0 Run id: 54545
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54545
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54545.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -65.23452622699298
# INFO     cost -65.23452622699298 +/- 0.0
# INFO     Run: 31 (trainer)
# INFO     params [ 1.93425691e+02  1.92955791e+02  1.91896133e+02  3.67010215e-02
#   8.39588771e-01 -1.12048213e+00  4.47009798e+00  7.50719026e-02
#   2.36636054e+00  3.49680936e-01  9.51138235e-01]
# 0 Run id: 54546
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54546
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54546.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -42.7515456740992
# INFO     cost -42.7515456740992 +/- 0.0
# INFO     Run: 32 (machine learner)
# INFO     params [ 1.92366961e+02  1.94115946e+02  1.92638273e+02  8.29876378e-02
#   3.68198285e-01 -1.98209652e+00  9.50000000e+00  1.01710691e-01
#   1.18655801e+00  6.00082098e-01  4.56292732e-01]
# 0 Run id: 54547
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54547
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54547.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -81.07973642159642
# INFO     cost -81.07973642159642 +/- 0.0
# INFO     Run: 33 (machine learner)
# INFO     params [ 1.92833247e+02  1.94033664e+02  1.92702855e+02  1.18025247e-01
#   3.17434746e-01 -1.32483994e+00  9.50000000e+00  1.02885244e-01
#   1.04101681e+00  4.51676986e-01  5.14284833e-01]
# 0 Run id: 54548
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54548
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54548.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -75.8136487985432
# INFO     cost -75.8136487985432 +/- 0.0
# INFO     Run: 34 (machine learner)
# INFO     params [ 1.92657162e+02  1.94392529e+02  1.92899152e+02  5.99183910e-02
#   3.26423872e-01 -1.63482887e+00  9.50000000e+00  1.06691049e-01
#   1.00678221e+00  5.61731182e-01  5.41526516e-01]
# 0 Run id: 54549
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54549
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54549.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -69.42401973947871
# INFO     cost -69.42401973947871 +/- 0.0
# INFO     Run: 35 (trainer)
# INFO     params [ 1.91606451e+02  1.92903977e+02  1.94400190e+02  2.99036313e-01
#   9.22202504e-01 -3.90605219e+00  8.46979369e+00  1.04854869e-01
#   2.86469380e+00  1.08520701e+00  4.11095052e-01]
# 0 Run id: 54550
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54550
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54550.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.32617551746156
# INFO     cost -40.32617551746156 +/- 0.0
# INFO     Run: 36 (machine learner)
# INFO     params [ 1.92681848e+02  1.94116895e+02  1.92929799e+02  9.74035341e-02
#   3.45262087e-01 -1.87520369e+00  9.50000000e+00  1.02137511e-01
#   1.46952977e+00  6.07748892e-01  4.50104064e-01]
# 0 Run id: 54551
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54551
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54551.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -71.70974353973696
# INFO     cost -71.70974353973696 +/- 0.0
# INFO     Run: 37 (machine learner)
# INFO     params [ 1.92559637e+02  1.93972973e+02  1.92520336e+02  9.91151034e-02
#   2.46419703e-01 -1.88508077e+00  9.50000000e+00  9.71613461e-02
#   1.26123040e+00  5.53768188e-01  4.21092714e-01]
# 0 Run id: 54552
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54552
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54552.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -84.2885633796354
# INFO     cost -84.2885633796354 +/- 0.0
# INFO     Run: 38 (machine learner)
# INFO     params [ 1.92526391e+02  1.93822851e+02  1.92470593e+02  1.08801787e-01
#   2.07246469e-01 -1.61831637e+00  9.50000000e+00  9.77835936e-02
#   1.14668404e+00  4.67719855e-01  4.84068467e-01]
# 0 Run id: 54553
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54553
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54553.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -83.4824329304672
# INFO     cost -83.4824329304672 +/- 0.0
# INFO     Run: 39 (trainer)
# INFO     params [ 1.94277492e+02  1.94575545e+02  1.92718799e+02  1.03980480e-01
#   3.00699431e-01 -3.35311014e+00  9.01396840e+00  1.04087756e-01
#   1.07599738e+00  2.30080988e-01  2.66481124e-01]
# 0 Run id: 54554
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54554
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54554.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -45.600331751532245
# INFO     cost -45.600331751532245 +/- 0.0
# INFO     Run: 40 (machine learner)
# INFO     params [ 1.92526764e+02  1.94013052e+02  1.92581541e+02  8.10287475e-02
#   1.61533494e-01 -1.27914164e+00  9.50000000e+00  9.58497322e-02
#   1.22416476e+00  6.68774082e-01  4.91030760e-01]
# 0 Run id: 54555
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54555
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54555.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -92.6798164260153
# INFO     cost -92.6798164260153 +/- 0.0
# INFO     Run: 41 (machine learner)
# INFO     params [ 1.92845757e+02  1.94012465e+02  1.92218050e+02  6.52395829e-02
#   2.64897370e-01 -1.63281705e+00  9.50000000e+00  9.99827568e-02
#   1.02990911e+00  5.36867774e-01  4.70484390e-01]
# 0 Run id: 54556
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54556
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54556.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -92.04031025464667
# INFO     cost -92.04031025464667 +/- 0.0
# INFO     Run: 42 (machine learner)
# INFO     params [ 1.93062760e+02  1.94080634e+02  1.92480752e+02  8.67229068e-02
#   2.21741941e-01 -1.52936070e+00  9.50000000e+00  9.95785366e-02
#   9.96234270e-01  5.41791039e-01  4.60655064e-01]
# 0 Run id: 54557
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54557
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54557.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -76.71668272613249
# INFO     cost -76.71668272613249 +/- 0.0
# INFO     Run: 43 (trainer)
# INFO     params [ 1.91851093e+02  1.93918590e+02  1.94101357e+02  1.28715068e-01
#   1.58293880e-01 -3.45034953e+00  8.85038053e+00  7.79376839e-02
#   2.88087903e+00  1.82304216e-01  2.29096406e-01]
# 0 Run id: 54558
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54558
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54558.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.479294960582955
# INFO     cost -41.479294960582955 +/- 0.0
# INFO     Run: 44 (machine learner)
# INFO     params [ 1.92357101e+02  1.93889705e+02  1.91343933e+02  2.00000000e-02
#   2.69778045e-01 -1.51972440e+00  9.50000000e+00  9.98813241e-02
#   1.42172366e+00  6.67198460e-01  5.03048431e-01]
# 0 Run id: 54559
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54559
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54559.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -102.49840880912706
# INFO     cost -102.49840880912706 +/- 0.0
# INFO     Run: 45 (machine learner)
# INFO     params [ 1.92550356e+02  1.94139029e+02  1.92355352e+02  7.84906449e-02
#   2.60196394e-01 -9.82417514e-01  9.50000000e+00  9.78281483e-02
#   1.12385574e+00  6.51801537e-01  5.91686616e-01]
# 0 Run id: 54560
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54560
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54560.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -73.79636831899755
# INFO     cost -73.79636831899755 +/- 0.0
# INFO     Run: 46 (machine learner)
# INFO     params [ 1.92135874e+02  1.93957522e+02  1.91946063e+02  2.00000000e-02
#   2.06304192e-01 -1.09120667e+00  9.50000000e+00  9.58567436e-02
#   1.21544633e+00  8.14384399e-01  5.38260914e-01]
# 0 Run id: 54561
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54561
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54561.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -72.6336555153574
# INFO     cost -72.6336555153574 +/- 0.0
# INFO     Run: 47 (trainer)
# INFO     params [ 1.94876532e+02  1.93225649e+02  1.92838614e+02  1.45900774e-01
#   1.01669529e-01 -3.97228614e+00  8.26870964e+00  8.95071379e-02
#   2.61538141e+00  1.31972770e+00  9.20711636e-01]
# 0 Run id: 54562
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54562
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54562.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -42.1231976367148
# INFO     cost -42.1231976367148 +/- 0.0
# INFO     Run: 48 (machine learner)
# INFO     params [ 1.92427957e+02  1.93798779e+02  1.90863933e+02  2.00000000e-02
#   3.09335783e-01 -1.96093447e+00  9.50000000e+00  1.08785976e-01
#   1.69918867e+00  5.48507976e-01  4.49448116e-01]
# 0 Run id: 54563
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54563
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54563.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -73.51988442854126
# INFO     cost -73.51988442854126 +/- 0.0
# INFO     Run: 49 (machine learner)
# INFO     params [ 1.92410745e+02  1.93867904e+02  1.91338391e+02  2.00000000e-02
#   3.05358258e-01 -1.87924339e+00  9.50000000e+00  9.57614226e-02
#   1.53092448e+00  6.56900310e-01  4.50590654e-01]
# 0 Run id: 54564
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54564
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54564.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -87.01765626674249
# INFO     cost -87.01765626674249 +/- 0.0
# INFO     Run: 50 (machine learner)
# INFO     params [ 1.92305107e+02  1.93885488e+02  1.91249568e+02  2.00000000e-02
#   2.39366691e-01 -1.64770854e+00  9.50000000e+00  9.88935775e-02
#   1.49694625e+00  6.11978894e-01  4.77338535e-01]
# 0 Run id: 54565
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54565
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54565.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -88.11131017858209
# INFO     cost -88.11131017858209 +/- 0.0
# INFO     Run: 51 (trainer)
# INFO     params [ 1.91931296e+02  1.93728770e+02  1.92568234e+02  2.73730256e-01
#   6.87216534e-02 -3.66700567e+00  6.11166962e+00  9.94272273e-02
#   4.12680623e-01  1.10614276e+00  8.01621790e-01]
# 0 Run id: 54566
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54566
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54566.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -81.70137290118443
# INFO     cost -81.70137290118443 +/- 0.0
# INFO     Run: 52 (machine learner)
# INFO     params [ 1.92539588e+02  1.93691018e+02  1.91365032e+02  2.00000000e-02
#   2.92445972e-01 -1.47432739e+00  9.50000000e+00  1.01846767e-01
#   1.22291655e+00  7.56018214e-01  4.15616439e-01]
# 0 Run id: 54567
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54567
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54567.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -77.22000632760006
# INFO     cost -77.22000632760006 +/- 0.0
# INFO     Run: 53 (machine learner)
# INFO     params [ 1.92511631e+02  1.93933395e+02  1.91374764e+02  2.00000000e-02
#   2.93417805e-01 -1.57487019e+00  9.50000000e+00  9.89007722e-02
#   1.29966091e+00  6.89297239e-01  4.93412057e-01]
# 0 Run id: 54568
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54568
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54568.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -82.63641485309073
# INFO     cost -82.63641485309073 +/- 0.0
# INFO     Run: 54 (machine learner)
# INFO     params [ 1.92243172e+02  1.93891334e+02  1.91096011e+02  2.00000000e-02
#   2.98873552e-01 -1.37035575e+00  9.50000000e+00  9.92263491e-02
#   1.45766825e+00  7.41847829e-01  5.00240259e-01]
# 0 Run id: 54569
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54569
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54569.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -63.63618532026396
# INFO     cost -63.63618532026396 +/- 0.0
# INFO     Run: 55 (trainer)
# INFO     params [1.93179467e+02 1.94134948e+02 1.92946549e+02 3.77201066e-01
#  3.90463547e-01 2.26701665e-01 7.40768996e+00 1.26503158e-01
#  4.83495467e-01 5.18020120e-01 7.85040668e-01]
# 0 Run id: 54570
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54570
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54570.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -43.894522640925096
# INFO     cost -43.894522640925096 +/- 0.0
# INFO     Run: 56 (machine learner)
# INFO     params [ 1.92365558e+02  1.93619946e+02  1.91725106e+02  2.00000000e-02
#   2.04563316e-01 -1.28300696e+00  9.50000000e+00  1.01972440e-01
#   1.29047556e+00  6.86318610e-01  3.87944822e-01]
# 0 Run id: 54571
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 54571
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 54571.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -72.0928706468424
# INFO     cost -72.0928706468424 +/- 0.0
# INFO     Run: 57 (machine learner)
# INFO     params [ 1.92258578e+02  1.94009935e+02  1.91876933e+02  2.00000000e-02
#   2.28909872e-01 -1.69076299e+00  9.50000000e+00  9.80775914e-02
#   1.25784034e+00  6.74577483e-01  5.33713109e-01]
# 0 Run id: 54572
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# ...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -60.41016102959812
# INFO     cost -60.41016102959812 +/- 0.0
# INFO     Run: 1162 (machine learner)
# INFO     params [1.93339900e+02 1.93295131e+02 1.94330897e+02 4.86615337e-01
#  4.80677325e-01 6.16410653e-01 9.50000000e+00 1.30000000e-01
#  1.38103947e+00 1.22786577e+00 1.00000000e-01]
# 0 Run id: 55677
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55677
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55677.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.351569980333835
# INFO     cost -40.351569980333835 +/- 0.0
# INFO     Run: 1163 (trainer)
# INFO     params [1.93045463e+02 1.94658618e+02 1.90955135e+02 2.32261581e-01
#  5.54800982e-01 4.12057929e-01 9.38245106e+00 8.56950777e-02
#  8.73931329e-01 1.32496581e+00 5.79583729e-01]
# 0 Run id: 55678
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55678
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55678.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -48.150025626457165
# INFO     cost -48.150025626457165 +/- 0.0
# INFO     Run: 1164 (machine learner)
# INFO     params [ 1.92893169e+02  1.93529285e+02  1.92543336e+02  2.00000000e-02
#   3.63692103e-01 -1.75975456e+00  7.85490510e+00  1.01704815e-01
#   1.63611834e+00  1.24452522e+00  2.79502178e-01]
# 0 Run id: 55679
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55679
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55679.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -86.99597406863943
# INFO     cost -86.99597406863943 +/- 0.0
# INFO     Run: 1165 (machine learner)
# INFO     params [ 1.92436634e+02  1.94408775e+02  1.92373983e+02  3.12534012e-01
#   2.89209103e-01 -2.83497873e+00  7.58252071e+00  1.30000000e-01
#   1.32423893e+00  1.01583036e+00  1.58656554e-01]
# 0 Run id: 55680
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55680
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55680.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -68.25618814749657
# INFO     cost -68.25618814749657 +/- 0.0
# INFO     Run: 1166 (machine learner)
# INFO     params [ 1.91310049e+02  1.93798157e+02  1.92649925e+02  2.00000000e-02
#   3.24833574e-01 -2.20894352e+00  9.35621261e+00  1.30000000e-01
#   9.82638518e-01  8.20107492e-01  3.39720804e-01]
# 0 Run id: 55681
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55681
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55681.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -86.72144958472177
# INFO     cost -86.72144958472177 +/- 0.0
# INFO     Run: 1167 (trainer)
# INFO     params [ 1.91041465e+02  1.92570973e+02  1.90740214e+02  2.59496050e-01
#   3.31082174e-01 -1.63394470e+00  9.16950725e+00  8.74974470e-02
#   3.97096563e-01  4.13890842e-01  5.22559358e-01]
# 0 Run id: 55682
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55682
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55682.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -43.9019834703119
# INFO     cost -43.9019834703119 +/- 0.0
# INFO     Run: 1168 (machine learner)
# INFO     params [ 1.92161902e+02  1.93713142e+02  1.91044649e+02  9.25123391e-02
#   3.67236566e-01 -2.56968220e+00  5.42135368e+00  1.26132291e-01
#   9.41097589e-01  1.34974806e+00  1.00000000e+00]
# 0 Run id: 55683
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55683
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55683.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -70.3742826052545
# INFO     cost -70.3742826052545 +/- 0.0
# INFO     Run: 1169 (machine learner)
# INFO     params [ 1.92661523e+02  1.92292233e+02  1.91895496e+02  1.67517197e-01
#   1.83072540e-01 -3.36014566e+00  5.96615024e+00  9.20854364e-02
#   1.18637485e+00  1.47912266e+00  5.01366237e-01]
# 0 Run id: 55684
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55684
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55684.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -64.08463723797443
# INFO     cost -64.08463723797443 +/- 0.0
# INFO     Run: 1170 (machine learner)
# INFO     params [ 1.91777217e+02  1.93350065e+02  1.91141620e+02  2.00000000e-02
#   6.01826915e-01 -3.14451341e+00  9.50000000e+00  1.08164086e-01
#   8.00028824e-01  1.50000000e+00  1.00000000e+00]
# 0 Run id: 55685
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55685
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55685.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -77.29906802947254
# INFO     cost -77.29906802947254 +/- 0.0
# INFO     Run: 1171 (trainer)
# INFO     params [1.92981328e+02 1.93113004e+02 1.90427031e+02 2.44525991e-01
#  2.17056097e-01 2.10331435e-01 6.45266166e+00 7.36283990e-02
#  2.22814914e+00 1.48674243e-01 2.00019842e-01]
# 0 Run id: 55686
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55686
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55686.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -39.624286433789855
# INFO     cost -39.624286433789855 +/- 0.0
# INFO     Run: 1172 (machine learner)
# INFO     params [ 1.93140197e+02  1.93130420e+02  1.93757044e+02  3.48909799e-01
#   5.09244232e-01 -5.89162094e-01  4.00000000e+00  9.70096577e-02
#   1.39899916e+00  4.57108729e-01  6.56077811e-01]
# 0 Run id: 55687
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55687
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55687.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -40.15526672594219
# INFO     cost -40.15526672594219 +/- 0.0
# INFO     Run: 1173 (machine learner)
# INFO     params [ 1.93079592e+02  1.94072504e+02  1.92459933e+02  2.00000000e-02
#   2.62936278e-01 -1.60780214e+00  8.50133951e+00  9.88926793e-02
#   1.57011411e+00  1.16678716e+00  4.49401349e-01]
# 0 Run id: 55688
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55688
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55688.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -92.94540998872668
# INFO     cost -92.94540998872668 +/- 0.0
# INFO     Run: 1174 (machine learner)
# INFO     params [ 1.92945970e+02  1.93835799e+02  1.92738539e+02  8.65233845e-02
#   4.32704785e-01 -1.55004406e+00  7.46137649e+00  1.02033134e-01
#   1.55231372e+00  9.93177021e-01  4.88219034e-01]
# 0 Run id: 55689
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55689
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55689.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -90.61075299230394
# INFO     cost -90.61075299230394 +/- 0.0
# INFO     Run: 1175 (trainer)
# INFO     params [ 1.91825686e+02  1.93038766e+02  1.92838947e+02  3.83975617e-01
#   2.11103969e-01 -6.66627863e-01  4.80931969e+00  9.44491132e-02
#   1.63896236e+00  1.00107436e+00  7.17763216e-01]
# 0 Run id: 55690
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55690
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55690.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -37.16720043854936
# INFO     cost -37.16720043854936 +/- 0.0
# INFO     Run: 1176 (machine learner)
# INFO     params [ 1.91654004e+02  1.92965286e+02  1.90000000e+02  1.20129000e-01
#   5.27933633e-01 -3.42956561e+00  4.00000000e+00  1.29901791e-01
#   4.02041615e-01  1.50000000e+00  1.00000000e+00]
# 0 Run id: 55691
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55691
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55691.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -51.34940186544073
# INFO     cost -51.34940186544073 +/- 0.0
# INFO     Run: 1177 (machine learner)
# INFO     params [ 1.92919163e+02  1.93726365e+02  1.92349288e+02  3.22838908e-02
#   3.43637203e-01 -1.64982463e+00  9.36673052e+00  9.84144946e-02
#   1.52222152e+00  1.12053452e+00  4.06620287e-01]
# 0 Run id: 55692
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55692
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55692.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -111.21358324805969
# INFO     cost -111.21358324805969 +/- 0.0
# INFO     Run: 1178 (machine learner)
# INFO     params [ 1.92180622e+02  1.93676501e+02  1.92905382e+02  1.36779412e-01
#   3.16651932e-01 -1.77380051e+00  7.83332666e+00  9.95802643e-02
#   1.79195552e+00  9.60856722e-01  3.24590480e-01]
# 0 Run id: 55693
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55693
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55693.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -77.08834481128946
# INFO     cost -77.08834481128946 +/- 0.0
# INFO     Run: 1179 (trainer)
# INFO     params [ 1.93251946e+02  1.94874527e+02  1.90644751e+02  2.05386331e-02
#   3.84445638e-01 -7.26187376e-01  7.31718828e+00  8.77216808e-02
#   2.26529048e+00  2.18344856e-01  6.28377572e-01]
# 0 Run id: 55694
#  3 values of dummy. 3 total shots. 9 total images expected.
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1060, 815], 'phase': 0.0, 'dimension': 0, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1060, y-center = 815
#
#  Run ID: 55694
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# No ROI saved in run 55694.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 54510.
# Using ROI loaded from run 54510.
# -41.749257068142114
# INFO     cost -41.749257068142114 +/- 0.0
# INFO     Controller finished. Closing down M-LOOP. Please wait a moment...
# INFO     Optimization ended because:
# INFO     	* Maximum number of runs reached.
# INFO     Results:
# INFO     	* Best parameters found: [ 1.92734453e+02  1.93992985e+02  1.92667695e+02  2.85081589e-02
#   2.96491964e-01 -1.36184873e+00  9.50000000e+00  9.29912598e-02
#   1.77755966e+00  1.06569025e+00  3.68910953e-01]
# INFO     	* Best cost returned: -123.27937041624307 +/- 0.0
# INFO     	* Best run index: 206
# INFO     	* Predicted best parameters:[ 1.92884478e+02  1.93846807e+02  1.92151852e+02  1.07461103e-01
#   4.56958693e-01 -1.99399737e+00  8.04211062e+00  1.24091039e-01
#   1.75490387e+00  1.10143692e+00  7.72413259e-01]
# INFO     	* Predicted best cost:-117.38534783423884
# INFO     M-LOOP Done.

# %%
#### uncomment this and run it if u wanna delete the logs


# import os, shutil
# # Specify the path of the file to be deleted
# folder = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_archives'
# file_path_2 = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_logs'

# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))

# for filename in os.listdir(file_path_2):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))
