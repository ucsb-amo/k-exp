# %%
# import vars 
import integration.lf_lib as lib
import os
import numpy as np

# from kexp.util.data.load_atomdata import load_atomdata
# from kexp.analysis.plotting_1d import *

# %%
var_names = ['i_lf_tweezer_load_current',
            'v_pd_lf_tweezer_1064_ramp_end',
            'v_lf_tweezer_paint_amp_max',
            'i_lf_tweezer_evap1_current',
            'v_pd_lf_tweezer_1064_rampdown_end',
            't_lf_tweezer_1064_rampdown',
            'i_lf_tweezer_evap2_current',
            'v_pd_lf_tweezer_1064_rampdown2_end',
            't_lf_tweezer_1064_rampdown2']
var_space = [[13.,18.],
             [4.,9.4],
             [-4.,6.],
             [12.,16.],
             [.15,4.],
             [0.02,0.4],
             [12.,16.],
             [0.07,.2],
             [.1,1.]]

# %%
#make table for vars
import pandas as pd


from kexp.config import expt_params

# Create an instance of the class
example_instance = expt_params.ExptParams()

# Prepare data for the table
data = []
for i, name in enumerate(var_names):
    default_value = getattr(example_instance, name, None)
    min_range, max_range = var_space[i]
    data.append([name, default_value, min_range, max_range])

# Create a DataFrame
df = pd.DataFrame(data, columns=["Variable Name", "Default Value", "Minimum Range Value", "Maximum Range Value"])

# Print the DataFrame
print(df)
# Out:
#                         Variable Name  Default Value  Minimum Range Value  \
# 0           i_lf_tweezer_load_current          15.20                13.00
# 1       v_pd_lf_tweezer_1064_ramp_end           9.00                 4.00
# 2          v_lf_tweezer_paint_amp_max           1.66                -4.00
# 3          i_lf_tweezer_evap1_current          14.00                12.00
# 4   v_pd_lf_tweezer_1064_rampdown_end           1.80                 0.15
# 5          t_lf_tweezer_1064_rampdown           0.10                 0.02
# 6          i_lf_tweezer_evap2_current          12.70                12.00
# 7  v_pd_lf_tweezer_1064_rampdown2_end           0.10                 0.07
# 8         t_lf_tweezer_1064_rampdown2           0.51                 0.10
#
#    Maximum Range Value
# 0                 18.0
# 1                  9.4
# 2                  6.0
# 3                 16.0
# 4                  4.0
# 5                  0.4
# 6                 16.0
# 7                  0.2
# 8                  1.0

# %%
def main():
    #M-LOOP can be run with three commands
    
    #First create your interface
    interface = lib.CustomInterface(var_names)
    #Next create the controller. 
    #The controller must take the variables to be changed in the vars object
    #vars = Param()


    controller = lib.mlc.create_controller(interface, 
                                       max_num_runs = 8000,
                                       target_cost = -109090000000,
                                       num_params = len(var_names),
                                       first_params = [15.5,9.4,4.5,12.7,.8,180.e-3,13.8,.11,400.e-3], 
                                       min_boundary = np.transpose(var_space)[0],
                                       max_boundary = np.transpose(var_space)[1],
                                       interface_file_type = 'txt',               #file types of *exp_input.mat* and *exp_output.mat*
                                       controller_archive_file_type = 'txt',      #file type of the controller archive
                                       learner_archive_file_type = 'txt')      #file type of the learner archive
    controller.optimize()

main()
# Out:
# INFO     M-LOOP version 3.3.4
# INFO     Optimization started.
# INFO     Run: 0 (training)
# INFO     params [15.5   9.4   4.5  12.7   0.8   0.18 13.8   0.11  0.4 ]
# 0 Run id: 28369
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28369
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28369.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -223.89586319184224
# INFO     cost -223.89586319184224 +/- 10.0
# INFO     Run: 1 (training)
# INFO     params [16.00112893  8.99340246  3.17956717 14.9106069   1.89877189  0.21143087
#  14.50996631  0.10872967  0.50225696]
# 0 Run id: 28370
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28370
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28370.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -220.04369514966643
# INFO     cost -220.04369514966643 +/- 10.0
# INFO     Run: 2 (training)
# INFO     params [13.72590921  8.48801903  5.30641835 13.93736273  2.00146377  0.29515484
#  15.0145984   0.19261849  0.38863442]
# 0 Run id: 28371
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28371
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28371.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -174.1628483541311
# INFO     cost -174.1628483541311 +/- 10.0
# INFO     Run: 3 (training)
# INFO     params [13.07435388  5.20488144  3.62033201 12.76428053  0.49770981  0.28140117
#  14.83125418  0.16910165  0.23459232]
# 0 Run id: 28372
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28372
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28372.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -191.01435182538745
# INFO     cost -191.01435182538745 +/- 10.0
# INFO     Run: 4 (training)
# INFO     params [15.50405269  7.55265896 -3.1869889  12.94905286  0.81433428  0.36299779
#  12.53624618  0.11893265  0.39979315]
# 0 Run id: 28373
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28373
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28373.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -153.10520618475906
# INFO     cost -153.10520618475906 +/- 10.0
# INFO     Run: 5 (training)
# INFO     params [16.46794148  8.52193271  2.73945867 12.558003    3.36184072  0.12732986
#  13.60315867  0.07882932  0.23154268]
# 0 Run id: 28374
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28374
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28374.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -174.53684451697308
# INFO     cost -174.53684451697308 +/- 10.0
# INFO     Run: 6 (training)
# INFO     params [16.19992126  8.16126667 -0.70406373 13.09945731  1.667545    0.33619755
#  15.04415991  0.13315979  0.333589  ]
# 0 Run id: 28375
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28375
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28375.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -174.80029494196637
# INFO     cost -174.80029494196637 +/- 10.0
# INFO     Run: 7 (training)
# INFO     params [1.60381244e+01 9.31396055e+00 1.46924535e-03 1.24327683e+01
#  3.94687048e+00 3.72813540e-01 1.46821477e+01 1.27807583e-01
#  1.20884539e-01]
# 0 Run id: 28376
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28376
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28376.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -137.97760145985498
# INFO     cost -137.97760145985498 +/- 10.0
# INFO     Run: 8 (training)
# INFO     params [17.16750229  8.49569739  2.38437892 12.86769975  2.90441119  0.13956183
#  15.27057389  0.16978228  0.94046045]
# 0 Run id: 28377
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28377
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28377.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -181.94091758421158
# INFO     cost -181.94091758421158 +/- 10.0
# INFO     Run: 9 (training)
# INFO     params [15.21693563  7.23781802 -2.57930951 14.73896398  2.07337823  0.33228339
#  15.62922847  0.1129842   0.29716204]
# 0 Run id: 28378
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28378
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28378.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -123.458852964227
# INFO     cost -123.458852964227 +/- 10.0
# INFO     Run: 10 (training)
# INFO     params [16.90882865  4.6644204   2.02763889 13.0073667   0.62279355  0.3094188
#  13.21765667  0.17765522  0.408724  ]
# 0 Run id: 28379
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28379
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28379.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -149.57348523365803
# INFO     cost -149.57348523365803 +/- 10.0
# INFO     Run: 11 (training)
# INFO     params [15.69943404  4.5985284  -3.64231921 12.95053537  3.22532908  0.13238682
#  14.54617625  0.08655956  0.27496613]
# 0 Run id: 28380
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28380
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28380.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -134.13322108222164
# INFO     cost -134.13322108222164 +/- 10.0
# INFO     Run: 12 (training)
# INFO     params [16.764418    5.39539931  0.39264062 15.65631275  2.60168633  0.26896373
#  14.42782531  0.13581691  0.38836812]
# 0 Run id: 28381
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28381
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28381.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -158.39359802090334
# INFO     cost -158.39359802090334 +/- 10.0
# INFO     Run: 13 (training)
# INFO     params [13.8935412   8.92840805 -2.03209232 15.25136689  1.68802848  0.22679588
#  15.45631914  0.18048294  0.18608493]
# 0 Run id: 28382
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28382
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28382.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -120.88523484856128
# INFO     cost -120.88523484856128 +/- 10.0
# INFO     Run: 14 (training)
# INFO     params [15.14601721  8.80703234 -1.91798236 15.25498352  3.75266069  0.21339596
#  15.59514351  0.09170673  0.28206706]
# 0 Run id: 28383
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28383
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28383.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -118.36052796047147
# INFO     cost -118.36052796047147 +/- 10.0
# INFO     Run: 15 (training)
# INFO     params [16.83923913  4.63248035  2.83778513 12.99597128  3.76972635  0.24333135
#  12.31992325  0.11656882  0.89651527]
# 0 Run id: 28384
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28384
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28384.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -140.83460711546076
# INFO     cost -140.83460711546076 +/- 10.0
# INFO     Run: 16 (training)
# INFO     params [13.41960887  4.32305581 -3.40808728 15.01090961  1.78421669  0.28001415
#  12.16643036  0.17695524  0.3525455 ]
# 0 Run id: 28385
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28385
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28385.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -130.18590577293523
# INFO     cost -130.18590577293523 +/- 10.0
# INFO     Run: 17 (training)
# INFO     params [15.61763193  8.7281278   4.44278068 13.97467884  0.17250398  0.23312104
#  12.67812624  0.1939529   0.22785392]
# 0 Run id: 28386
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28386
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28386.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -133.32734931787886
# INFO     cost -133.32734931787886 +/- 10.0
# INFO     Run: 18 (training)
# INFO     params [16.28386333  8.92769701  1.41511061 13.62136369  0.95310705  0.13973679
#  13.39055481  0.16749017  0.6855546 ]
# 0 Run id: 28387
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28387
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28387.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -169.98497872896226
# INFO     cost -169.98497872896226 +/- 10.0
# INFO     Run: 19 (trainer)
# INFO     params [17.83259868  4.99816023  0.95006997 15.9302904   1.20352507  0.13188828
#  12.19971069  0.18751104  0.59978841]
# 0 Run id: 28388
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28388
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28388.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -137.09355103413967
# INFO     cost -137.09355103413967 +/- 10.0
# INFO     Run: 20 (machine learner)
# INFO     params [15.99222694  9.18279231  5.74418632 13.6431667   1.13074961  0.20658112
#  14.8214733   0.08992056  0.56616544]
# 0 Run id: 28389
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28389
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28389.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -161.77931736143805
# INFO     cost -161.77931736143805 +/- 10.0
# INFO     Run: 21 (machine learner)
# INFO     params [16.14566194  9.0467102   6.         13.56947551  0.97801747  0.21704579
#  15.15130948  0.08469368  0.61858089]
# 0 Run id: 28390
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28390
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28390.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -167.8308456254046
# INFO     cost -167.8308456254046 +/- 10.0
# INFO     Run: 22 (machine learner)
# INFO     params [16.28953859  8.90734128  6.         13.48408774  0.78534973  0.22689993
#  15.45067444  0.07959079  0.66733993]
# 0 Run id: 28391
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28391
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28391.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -156.485955280351
# INFO     cost -156.485955280351 +/- 10.0
# INFO     Run: 23 (machine learner)
# INFO     params [15.88304148  9.25568268  5.10219472 13.63893063  1.21360838  0.19903789
#  14.54391585  0.09536037  0.51998738]
# 0 Run id: 28392
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28392
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28392.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -212.3831684916433
# INFO     cost -212.3831684916433 +/- 10.0
# INFO     Run: 24 (trainer)
# INFO     params [14.4974135   8.50360101  3.54839239 12.34571609  0.27458657  0.03262441
#  15.98173506  0.15184708  0.64558454]
# 0 Run id: 28393
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28393
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28393.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -119.10307119894334
# INFO     cost -119.10307119894334 +/- 10.0
# INFO     Run: 25 (machine learner)
# INFO     params [15.62580585  9.37483309  3.16206837 13.64164493  1.52432721  0.18355207
#  13.83558189  0.11024355  0.39308425]
# 0 Run id: 28394
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28394
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28394.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -271.12905298142493
# INFO     cost -271.12905298142493 +/- 10.0
# INFO     Run: 26 (machine learner)
# INFO     params [15.47055873  9.4         2.91953939 13.78372657  1.56903716  0.17472455
#  13.60047165  0.1057229   0.36566032]
# 0 Run id: 28395
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28395
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28395.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -186.6313806054897
# INFO     cost -186.6313806054897 +/- 10.0
# INFO     Run: 27 (machine learner)
# INFO     params [15.24069316  9.4         2.79544417 13.98476474  1.50684814  0.16207775
#  13.3145844   0.09795519  0.3505657 ]
# 0 Run id: 28396
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28396
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28396.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -207.62800645400733
# INFO     cost -207.62800645400733 +/- 10.0
# INFO     Run: 28 (machine learner)
# INFO     params [15.66134746  9.29119013  3.47394837 13.53525286  1.4055281   0.18696472
#  13.94332912  0.11071207  0.41281849]
# 0 Run id: 28397
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28397
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28397.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -188.25857129695183
# INFO     cost -188.25857129695183 +/- 10.0
# INFO     Run: 29 (trainer)
# INFO     params [16.63909129  4.90920388  0.97777252 13.701728    2.25084853  0.23013544
#  12.67949176  0.07757908  0.34813647]
# 0 Run id: 28398
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28398
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28398.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -206.58244357002704
# INFO     cost -206.58244357002704 +/- 10.0
# INFO     Run: 30 (machine learner)
# INFO     params [16.26355923  9.4         4.34141932 13.74707782  1.82803673  0.19894995
#  13.48166516  0.10920373  0.39658955]
# 0 Run id: 28399
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28399
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28399.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -208.66087063031404
# INFO     cost -208.66087063031404 +/- 10.0
# INFO     Run: 31 (machine learner)
# INFO     params [17.49463173  9.4         4.6497779  14.18998514  1.90772201  0.18969129
#  13.4167466   0.10974651  0.34655618]
# 0 Run id: 28400
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28400
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28400.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -200.68295402264135
# INFO     cost -200.68295402264135 +/- 10.0
# INFO     Run: 32 (machine learner)
# INFO     params [18.          9.4         5.27522422 14.55954579  1.94964418  0.15966731
#  13.48409693  0.11062073  0.26580802]
# 0 Run id: 28401
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28401
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28401.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -174.2519921933356
# INFO     cost -174.2519921933356 +/- 10.0
# INFO     Run: 33 (machine learner)
# INFO     params [15.82210125  9.4         3.78270107 13.61516507  1.58285843  0.18925877
#  13.65015025  0.1061574   0.39269657]
# 0 Run id: 28402
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28402
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28402.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -188.37514845381682
# INFO     cost -188.37514845381682 +/- 10.0
# INFO     Run: 34 (trainer)
# INFO     params [15.04208024  8.48312574  1.77958226 15.68274734  1.95540604  0.38968697
#  15.86343553  0.09634611  0.38723205]
# 0 Run id: 28403
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28403
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28403.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -131.45372315072746
# INFO     cost -131.45372315072746 +/- 10.0
# INFO     Run: 35 (machine learner)
# INFO     params [15.27422267  9.4         3.44549854 13.20077425  1.2170209   0.21208499
#  13.00108527  0.08288231  0.40904888]
# 0 Run id: 28404
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28404
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28404.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -166.0598604482256
# INFO     cost -166.0598604482256 +/- 10.0
# INFO     Run: 36 (machine learner)
# INFO     params [14.84001098  7.02203145  4.84591049 13.12513873  1.0193346   0.2181091
#  12.81438187  0.07        0.21912852]
# 0 Run id: 28405
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28405
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28405.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -170.56308274539566
# INFO     cost -170.56308274539566 +/- 10.0
# INFO     Run: 37 (machine learner)
# INFO     params [14.37201632  6.53446935  5.6509555  12.89652339  0.97094315  0.22704325
#  12.8007278   0.07        0.1400198 ]
# 0 Run id: 28406
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28406
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28406.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -195.87713839440653
# INFO     cost -195.87713839440653 +/- 10.0
# INFO     Run: 38 (machine learner)
# INFO     params [15.53657185  9.4         3.51573214 13.53886983  1.44643792  0.19352504
#  13.42619759  0.09707205  0.40781138]
# 0 Run id: 28407
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28407
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28407.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -235.76383303418862
# INFO     cost -235.76383303418862 +/- 10.0
# INFO     Run: 39 (trainer)
# INFO     params [15.35306657  6.43463505 -1.66675321 12.5768491   1.31267443  0.23059049
#  13.77733952  0.19830627  0.9651486 ]
# 0 Run id: 28408
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28408
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28408.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -161.42049545463033
# INFO     cost -161.42049545463033 +/- 10.0
# INFO     Run: 40 (machine learner)
# INFO     params [15.45323694  9.4         4.12387577 14.16297317  2.17876703  0.13474934
#  13.74574942  0.11648604  0.52416866]
# 0 Run id: 28409
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28409
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28409.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -194.18207423920825
# INFO     cost -194.18207423920825 +/- 10.0
# INFO     Run: 41 (machine learner)
# INFO     params [14.90894556  9.4         5.1922818  14.6291616   2.63911633  0.10431273
#  13.56220857  0.1192529   0.61539592]
# 0 Run id: 28410
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28410
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28410.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -221.9033926495379
# INFO     cost -221.9033926495379 +/- 10.0
# INFO     Run: 42 (machine learner)
# INFO     params [14.59895312  9.4         5.82184804 14.92422417  2.87720536  0.08466104
#  13.45475236  0.12015851  0.66505777]
# 0 Run id: 28411
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28411
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28411.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -203.74428710559596
# INFO     cost -203.74428710559596 +/- 10.0
# INFO     Run: 43 (machine learner)
# INFO     params [15.79394341  9.4         3.53284727 13.83470316  1.73509605  0.1652245
#  13.83762745  0.1122199   0.43672304]
# 0 Run id: 28412
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28412
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28412.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -211.47699568371337
# INFO     cost -211.47699568371337 +/- 10.0
# INFO     Run: 44 (trainer)
# INFO     params [13.51173154  6.46302064  3.44112611 15.54220552  3.59134233  0.35682413
#  12.86015575  0.10940766  0.39123062]
# 0 Run id: 28413
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28413
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28413.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -198.81798925791702
# INFO     cost -198.81798925791702 +/- 10.0
# INFO     Run: 45 (machine learner)
# INFO     params [15.37186528  9.4         4.01962756 14.84716677  1.98547312  0.09566175
#  13.24845262  0.09658604  0.56339405]
# 0 Run id: 28414
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28414
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28414.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -197.81795563016746
# INFO     cost -197.81795563016746 +/- 10.0
# INFO     Run: 46 (machine learner)
# INFO     params [15.83566202  9.4         2.47972718 15.87528188  1.70949646  0.0480796
#  12.96588234  0.0723735   0.72712816]
# 0 Run id: 28415
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28415
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28415.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -131.3212891519974
# INFO     cost -131.3212891519974 +/- 10.0
# INFO     Run: 47 (machine learner)
# INFO     params [16.1892173   9.4         1.43111333 16.          1.65009767  0.02
#  12.86428407  0.07        0.84386527]
# 0 Run id: 28416
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28416
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28416.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -153.4408696653617
# INFO     cost -153.4408696653617 +/- 10.0
# INFO     Run: 48 (machine learner)
# INFO     params [15.33958521  9.4         4.44759961 14.24503627  2.10292679  0.13509763
#  13.48978593  0.10919441  0.50368763]
# 0 Run id: 28417
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28417
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28417.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -210.59192756264753
# INFO     cost -210.59192756264753 +/- 10.0
# INFO     Run: 49 (trainer)
# INFO     params [16.79082054  5.60949037  4.88741485 15.86692489  3.19218072  0.30202768
#  14.28469351  0.16914997  0.16544995]
# 0 Run id: 28418
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28418
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28418.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -112.37822870913527
# INFO     cost -112.37822870913527 +/- 10.0
# INFO     Run: 50 (machine learner)
# INFO     params [14.4913745   9.4         6.         14.08154246  2.57337835  0.19092426
#  13.63922726  0.12336869  0.432452  ]
# 0 Run id: 28419
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28419
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28419.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -191.10094942460165
# INFO     cost -191.10094942460165 +/- 10.0
# INFO     Run: 51 (machine learner)
# INFO     params [13.33124664  9.4         6.         13.99972696  2.88107858  0.20905426
#  13.37332234  0.12016619  0.40690297]
# 0 Run id: 28420
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28420
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28420.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -213.64059065126474
# INFO     cost -213.64059065126474 +/- 10.0
# INFO     Run: 52 (machine learner)
# INFO     params [13.          9.4         6.         14.10438018  3.37142649  0.29065176
#  12.915114    0.12588562  0.69245525]
# 0 Run id: 28421
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28421
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28421.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -172.16022214125607
# INFO     cost -172.16022214125607 +/- 10.0
# INFO     Run: 53 (machine learner)
# INFO     params [15.06643992  9.4         4.99088355 14.00222615  2.27040969  0.17280905
#  13.73474682  0.12090489  0.45567178]
# 0 Run id: 28422
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28422
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28422.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -222.7225533624872
# INFO     cost -222.7225533624872 +/- 10.0
# INFO     Run: 54 (trainer)
# INFO     params [15.61890387  8.60546323 -1.47483288 13.21151293  1.71830735  0.0345817
#  13.30634341  0.1783037   0.54123756]
# 0 Run id: 28423
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28423
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28423.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -147.48193691840697
# INFO     cost -147.48193691840697 +/- 10.0
# INFO     Run: 55 (machine learner)
# INFO     params [14.52959521  9.4         5.38220265 13.66432944  2.09106973  0.10381784
#  13.83784666  0.11728543  0.29505953]
# 0 Run id: 28424
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28424
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28424.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -178.5769565680798
# INFO     cost -178.5769565680798 +/- 10.0
# INFO     Run: 56 (machine learner)
# INFO     params [13.68111867  9.4         6.         13.62611126  2.02730433  0.03274769
#  13.85560833  0.11292868  0.11483719]
# 0 Run id: 28425
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28425
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28425.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -138.4005232180019
# INFO     cost -138.4005232180019 +/- 10.0
# INFO     Run: 57 (machine learner)
# INFO     params [13.          9.4         6.         13.52819986  1.95842044  0.02
#  13.89849835  0.10883406  0.1       ]
# 0 Run id: 28426
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28426
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28426.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -137.06834094746515
# INFO     cost -137.06834094746515 +/- 10.0
# INFO     Run: 58 (machine learner)
# INFO     params [15.05329844  9.4         4.63105105 13.80525807  2.09069285  0.15122265
#  13.77669018  0.11763977  0.41090509]
# 0 Run id: 28427
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28427
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28427.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -209.0336339338471
# INFO     cost -209.0336339338471 +/- 10.0
# INFO     Run: 59 (trainer)
# INFO     params [14.83495378  4.26016178 -3.36005257 14.78380162  2.54815645  0.20513606
#  13.49762586  0.16890775  0.69494731]
# 0 Run id: 28428
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28428
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28428.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -132.6044284884825
# INFO     cost -132.6044284884825 +/- 10.0
# INFO     Run: 60 (machine learner)
# INFO     params [15.51345452  9.4         3.79662565 14.09302688  2.21740978  0.22111689
#  13.74712208  0.12213509  0.59199119]
# 0 Run id: 28429
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28429
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28429.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -200.61795424836131
# INFO     cost -200.61795424836131 +/- 10.0
# INFO     Run: 61 (machine learner)
# INFO     params [15.88332587  9.4         3.49394664 14.22512777  2.53058929  0.25171541
#  13.67562311  0.12562186  0.71583002]
# 0 Run id: 28430
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28430
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28430.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -207.54768254238286
# INFO     cost -207.54768254238286 +/- 10.0
# INFO     Run: 62 (machine learner)
# INFO     params [13.99308237  4.          4.92754058 14.12888848  2.99798204  0.32606158
#  12.          0.07        0.1       ]
# 0 Run id: 28431
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28431
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28431.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -167.28190975454288
# INFO     cost -167.28190975454288 +/- 10.0
# INFO     Run: 63 (machine learner)
# INFO     params [15.53062831  9.4         3.90881867 14.04676688  2.05904745  0.20304286
#  13.78892253  0.11860392  0.52709841]
# 0 Run id: 28432
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28432
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28432.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -195.24589813564896
# INFO     cost -195.24589813564896 +/- 10.0
# INFO     Run: 64 (trainer)
# INFO     params [17.95065382  7.9290115  -3.18392753 12.88628948  3.99284233  0.22248492
#  15.96857988  0.13559672  0.65133535]
# 0 Run id: 28433
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28433
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28433.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -123.12887682531161
# INFO     cost -123.12887682531161 +/- 10.0
# INFO     Run: 65 (machine learner)
# INFO     params [15.74636508  9.4         4.00179644 13.81980935  2.1432995   0.19594688
#  13.72725345  0.11755717  0.52400005]
# 0 Run id: 28434
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28434
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28434.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -206.45482940117782
# INFO     cost -206.45482940117782 +/- 10.0
# INFO     Run: 66 (machine learner)
# INFO     params [17.64271275  9.4         1.45649027 12.01748823  0.17701819  0.19042438
#  14.30227445  0.10087807  0.13893028]
# 0 Run id: 28435
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28435
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28435.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -124.1003856895252
# INFO     cost -124.1003856895252 +/- 10.0
# INFO     Run: 67 (machine learner)
# INFO     params [15.44837177  9.4         6.         16.          4.          0.07448359
#  15.16875136  0.16809769  1.        ]
# 0 Run id: 28436
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 28436
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 28436.
# ...
# -92.16592762866463
# INFO     cost -92.16592762866463 +/- 10.0
# INFO     Run: 644 (trainer)
# INFO     params [13.36298481  5.20633835 -1.02544448 13.57122243  2.23563072  0.30130682
#  15.62922847  0.08638535  0.30608313]
# 0 Run id: 29013
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29013
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29013.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -91.61464498662126
# INFO     cost -91.61464498662126 +/- 10.0
# INFO     Run: 645 (machine learner)
# INFO     params [16.37043265  9.4         3.3623513  14.11694156  4.          0.10920181
#  12.59959008  0.14211512  0.17569807]
# 0 Run id: 29014
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29014
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29014.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -107.73319311737487
# INFO     cost -107.73319311737487 +/- 10.0
# INFO     Run: 646 (machine learner)
# INFO     params [16.37638071  9.4         3.36058642 14.10777745  4.          0.10651185
#  12.5728369   0.14127366  0.17305016]
# 0 Run id: 29015
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29015
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29015.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -106.97083211257657
# INFO     cost -106.97083211257657 +/- 10.0
# INFO     Run: 647 (machine learner)
# INFO     params [13.          9.39995155  6.         12.          4.          0.02
#  12.          0.07        1.        ]
# 0 Run id: 29016
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29016
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29016.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -118.08834930887309
# INFO     cost -118.08834930887309 +/- 10.0
# INFO     Run: 648 (machine learner)
# INFO     params [16.37637002  9.4         3.33090859 14.13655973  4.          0.1114751
#  12.62337345  0.1433443   0.17700256]
# 0 Run id: 29017
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29017
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29017.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# attempt to get argmin of an empty sequence
# -109.35821333526387
# INFO     cost -109.35821333526387 +/- 10.0
# INFO     Run: 649 (trainer)
# INFO     params [16.90882865  4.15405047  2.02763889 15.33469088  0.62279355  0.25230078
#  13.50835984  0.19984139  0.70248341]
# 0 Run id: 29018
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29018
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29018.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -94.1057933929477
# INFO     cost -94.1057933929477 +/- 10.0
# INFO     Run: 650 (machine learner)
# INFO     params [18.         9.3999838 -4.        16.         4.         0.4
#  16.         0.2        1.       ]
# 0 Run id: 29019
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29019
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29019.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -115.09164353708321
# INFO     cost -115.09164353708321 +/- 10.0
# INFO     Run: 651 (machine learner)
# INFO     params [18.          9.39996112 -4.         16.          4.          0.4
#  16.          0.2         1.        ]
# 0 Run id: 29020
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29020
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29020.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -102.33180111339823
# INFO     cost -102.33180111339823 +/- 10.0
# INFO     Run: 652 (machine learner)
# INFO     params [18.          9.39993851 -4.         16.          4.          0.4
#  16.          0.2         1.        ]
# 0 Run id: 29021
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29021
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29021.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -94.72688491710095
# INFO     cost -94.72688491710095 +/- 10.0
# INFO     Run: 653 (machine learner)
# INFO     params [16.46823217  9.4         2.98980688 14.29389672  4.          0.11757253
#  12.66981685  0.1513665   0.17963054]
# 0 Run id: 29022
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29022
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29022.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# Optimal parameters not found: The maximum number of function evaluations is exceeded.
# -104.15147846246565
# INFO     cost -104.15147846246565 +/- 10.0
# INFO     Run: 654 (trainer)
# INFO     params [14.88952197  6.06911488  5.85597079 12.86228946  3.30741899  0.13238682
#  13.27137127  0.08655956  0.73767931]
# 0 Run id: 29023
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29023
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29023.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -110.65421071031786
# INFO     cost -110.65421071031786 +/- 10.0
# INFO     Run: 655 (machine learner)
# INFO     params [16.1977746   9.4         5.26045053 16.          4.          0.21529496
#  12.80090908  0.2         0.1       ]
# 0 Run id: 29024
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29024
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29024.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -107.59728198498068
# INFO     cost -107.59728198498068 +/- 10.0
# INFO     Run: 656 (machine learner)
# INFO     params [16.16135638  9.4         6.         16.          4.          0.22690271
#  12.83761     0.2         0.1       ]
# 0 Run id: 29025
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29025
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29025.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -112.22098253801629
# INFO     cost -112.22098253801629 +/- 10.0
# INFO     Run: 657 (machine learner)
# INFO     params [16.16709076  9.4         6.         16.          4.          0.24065786
#  12.82156573  0.2         0.1       ]
# 0 Run id: 29026
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29026
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29026.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -105.27327305960037
# INFO     cost -105.27327305960037 +/- 10.0
# INFO     Run: 658 (machine learner)
# INFO     params [16.23579474  9.4         4.77074691 16.          4.          0.20691843
#  12.76966731  0.2         0.1       ]
# 0 Run id: 29027
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29027
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29027.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -110.01977950518058
# INFO     cost -110.01977950518058 +/- 10.0
# INFO     Run: 659 (trainer)
# INFO     params [16.08743207  5.39539931  4.96635203 14.91893133  2.25814608  0.29966965
#  14.72170908  0.07939502  0.64956085]
# 0 Run id: 29028
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29028
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29028.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -100.02165590495316
# INFO     cost -100.02165590495316 +/- 10.0
# INFO     Run: 660 (machine learner)
# INFO     params [14.86874404  5.81159605  5.08514913 13.5205221   3.41375644  0.19857356
#  13.35851309  0.19843549  0.78168329]
# 0 Run id: 29029
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29029
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29029.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -96.85555542651143
# INFO     cost -96.85555542651143 +/- 10.0
# INFO     Run: 661 (machine learner)
# INFO     params [16.51500634  8.18045742  3.06948398 12.8002795   3.24364448  0.07204899
#  15.21892224  0.18203844  0.99258072]
# 0 Run id: 29030
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29030
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29030.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -106.46786605473355
# INFO     cost -106.46786605473355 +/- 10.0
# INFO     Run: 662 (machine learner)
# INFO     params [16.91918053  9.39997839  0.56689131 14.85795843  4.          0.22100573
#  13.89625715  0.16581992  0.48255398]
# 0 Run id: 29031
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29031
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29031.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -109.18852582425689
# INFO     cost -109.18852582425689 +/- 10.0
# INFO     Run: 663 (machine learner)
# INFO     params [16.34529098  9.4         3.40611955 14.19752601  4.          0.12940705
#  12.79533628  0.14877338  0.19693089]
# 0 Run id: 29032
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29032
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29032.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -104.82443337585272
# INFO     cost -104.82443337585272 +/- 10.0
# INFO     Run: 664 (trainer)
# INFO     params [15.39595437  5.71297287 -2.03209232 14.3183118   3.92415385  0.13174823
#  15.12890425  0.15068923  0.40131996]
# 0 Run id: 29033
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29033
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29033.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -103.34124542328611
# INFO     cost -103.34124542328611 +/- 10.0
# INFO     Run: 665 (machine learner)
# INFO     params [16.35059289  9.4         3.41272595 14.22685559  4.          0.13059171
#  12.8084057   0.1498932   0.20311828]
# 0 Run id: 29034
#  1 values of dummy. 1 total shots. 3 total images expected.
# andor
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [1141, 965], 'phase': 0.0, 'dimension': 0}
# -> mask: spot, dimension = 0 um, phase = 0.0 pi, x-center = 1141, y-center = 965
#
#  Run ID: 29034
# Parameters saved, data closed.
# Done!
#
# No ROI saved in run 29034.
# ROI specified by Run ID. Attempting to load ROI...
# ROI loaded from run 28073.
# Using ROI loaded from run 28073.
# -100.98035277620016
# INFO     cost -100.98035277620016 +/- 10.0
# INFO     Run: 666 (machine learner)
# INFO     params [15.84609185  7.95923721  4.53259416 14.74210575  3.27532305  0.27067087
#  13.00963558  0.13220249  0.72807293]

# %%
def param_format(param_values,param_keys=var_names):
    lines = ""
    for i in range(len(param_keys)):
            lines += f"""
                self.p.{param_keys[i]} = {float(param_values[i])}"""
    print(lines)

param_format([-3.15221506,  0.10830731, -1.20206951, -2.93364217,  0.17977458,  0.1727242,
  1.96822209, -1.59931595, -3.91874333,  0.2,         0.09954919, 17.40341653])
# Out:
#                 self.p.detune_push = -3.15221506
#                 self.p.amp_push = 0.10830731
#                 self.p.detune_d2_c_2dmot = -1.20206951
#                 self.p.detune_d2_r_2dmot = -2.93364217
#                 self.p.amp_d2_c_2dmot = 0.17977458
#                 self.p.amp_d2_r_2dmot = 0.1727242
#                 self.p.v_2d_mot_current = 1.96822209
#                 self.p.detune_d2_c_mot = -1.59931595
#                 self.p.detune_d2_r_mot = -3.91874333
#                 self.p.amp_d2_c_mot = 0.2
#                 self.p.amp_d2_r_mot = 0.09954919
#                 self.p.i_mot = 17.40341653

# %%
def print_default_params(param_keys=var_names):
    from kexp.config import ExptParams
    p = ExptParams()
    lines = ""
    for key in param_keys:
            lines += f"""
                self.p.{key} = {float(vars(p)[key])}"""
    print(lines)
print_default_params()
# Out:
#                 self.p.detune_push = -2.4
#                 self.p.amp_push = 0.13
#                 self.p.detune_d2_c_2dmot = -1.2
#                 self.p.detune_d2_r_2dmot = -2.4
#                 self.p.amp_d2_c_2dmot = 0.188
#                 self.p.amp_d2_r_2dmot = 0.188
#                 self.p.v_2d_mot_current = 2.11
#                 self.p.detune_d2_c_mot = -2.4
#                 self.p.detune_d2_r_mot = -4.2
#                 self.p.amp_d2_c_mot = 0.188
#                 self.p.amp_d2_r_mot = 0.188
#                 self.p.i_mot = 20.0

# %%
def print_mloop_param_bounds(param_keys=var_names,param_bounds=var_space):
    lines = ""
    for i in range(len(param_keys)):
            lines += f"""
                self.p.{param_keys[i]} \u2208 {var_space[i]}"""
    print(lines)
print_mloop_param_bounds()
# Out:
#                 self.p.detune_push ∈ [-5.4, 0.6]
#                 self.p.amp_push ∈ [0.01, 0.2]
#                 self.p.detune_d2_c_2dmot ∈ [-4.2, 1.8]
#                 self.p.detune_d2_r_2dmot ∈ [-5.4, 0.6]
#                 self.p.amp_d2_c_2dmot ∈ [0.01, 0.2]
#                 self.p.amp_d2_r_2dmot ∈ [0.01, 0.2]
#                 self.p.v_2d_mot_current ∈ [0.5, 5.0]
#                 self.p.detune_d2_c_mot ∈ [-5.4, 0.6]
#                 self.p.detune_d2_r_mot ∈ [-7.2, -1.2]
#                 self.p.amp_d2_c_mot ∈ [0.01, 0.2]
#                 self.p.amp_d2_r_mot ∈ [0.01, 0.2]
#                 self.p.i_mot ∈ [15.0, 25.0]

# %%
def print_param_report(mloop_params,param_keys=var_names,param_bounds=var_space):
    from kexp.config import ExptParams
    p = ExptParams()
    lines = ""
    for i in range(len(param_keys)):
            line = []
            line.append(f"self.p.{param_keys[i]}".ljust(25,' '))
            line.append(f" \u2208 {var_space[i]}:".ljust(20,' '))
            line.append(f"mloop = {mloop_params[i]:1.3f},   ".ljust(18,' '))
            line.append(f"default = {vars(p)[param_keys[i]]:1.3f}".ljust(15,' '))
            s = ""
            for L in line:
                s += L
            lines += f"""
                {s}"""
    return lines
lines = print_param_report([-3.15221506,  0.10830731, -1.20206951, -2.93364217,  0.17977458,  0.1727242,
  1.96822209, -1.59931595, -3.91874333,  0.2,         0.09954919, 17.40341653])
print(lines)
# Out:
#                 self.p.detune_push        ∈ [-5.4, 0.6]:     mloop = -3.152,   default = -2.400
#                 self.p.amp_push           ∈ [0.01, 0.2]:     mloop = 0.108,    default = 0.130
#                 self.p.detune_d2_c_2dmot  ∈ [-4.2, 1.8]:     mloop = -1.202,   default = -1.200
#                 self.p.detune_d2_r_2dmot  ∈ [-5.4, 0.6]:     mloop = -2.934,   default = -2.400
#                 self.p.amp_d2_c_2dmot     ∈ [0.01, 0.2]:     mloop = 0.180,    default = 0.188
#                 self.p.amp_d2_r_2dmot     ∈ [0.01, 0.2]:     mloop = 0.173,    default = 0.188
#                 self.p.v_2d_mot_current   ∈ [0.5, 5.0]:      mloop = 1.968,    default = 2.110
#                 self.p.detune_d2_c_mot    ∈ [-5.4, 0.6]:     mloop = -1.599,   default = -2.400
#                 self.p.detune_d2_r_mot    ∈ [-7.2, -1.2]:    mloop = -3.919,   default = -4.200
#                 self.p.amp_d2_c_mot       ∈ [0.01, 0.2]:     mloop = 0.200,    default = 0.188
#                 self.p.amp_d2_r_mot       ∈ [0.01, 0.2]:     mloop = 0.100,    default = 0.188
#                 self.p.i_mot              ∈ [15.0, 25.0]:    mloop = 17.403,   default = 20.000

# %%
#### uncomment this and run it if u wanna delete the logs


# import os, shutil
# # Specify the path of the file to be deleted
# folder = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_archives'
# file_path_2 = r'C:\Users\bananas\code\k-exp\kexp\experiments\Mloop testing\M-LOOP_logs'

# for filename in os.listdir(folder):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))

# for filename in os.listdir(file_path_2):
#     file_path = os.path.join(folder, filename)
#     try:
#         if os.path.isfile(file_path) or os.path.islink(file_path):
#             os.unlink(file_path)
#         elif os.path.isdir(file_path):
#             shutil.rmtree(file_path)
#     except Exception as e:
#         print('Failed to delete %s. Reason: %s' % (file_path, e))
