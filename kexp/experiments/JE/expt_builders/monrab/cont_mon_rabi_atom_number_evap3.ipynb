# %%
import numpy as np
from subprocess import PIPE, run
import matplotlib.pyplot as plt
import os
import textwrap
from waxx.control import ethernet_relay

class ExptBuilder():
    def __init__(self):
        self.__code_path__ = os.environ.get('code')
        self.__temp_exp_path__ = os.path.join(self.__code_path__, "k-exp", "kexp", "experiments", "ml_expt.py")

    def run_expt(self):
        expt_path = self.__temp_exp_path__
        run_expt_command = r"%kpy% & artiq_run " + expt_path
        result = run(run_expt_command, stdout=PIPE, stderr=PIPE, universal_newlines=True, shell=True)
        print(result.returncode, result.stdout, result.stderr)
        os.remove(self.__temp_exp_path__)
        return result.returncode
    
    def write_experiment_to_file(self, program):
        with open(self.__temp_exp_path__, 'w') as file:
            file.write(program)
    
    def fringe_scan_expt(self, t_evap, ramp_end):
        script = textwrap.dedent(f"""
        from artiq.experiment import *
        from artiq.experiment import delay
        from kexp import Base, img_types, cameras
        import numpy as np
        from kexp.calibrations.tweezer import tweezer_vpd1_to_vpd2
        from kexp.calibrations.imaging import high_field_imaging_detuning
        from artiq.coredevice.sampler import Sampler
        from artiq.language import now_mu
        from kexp.util.artiq.async_print import aprint

        class cont_mon_182_ref(EnvExperiment, Base):

            def prepare(self):
                Base.__init__(self,setup_camera=True,
                            camera_select=cameras.andor,
                            save_data=True,
                            imaging_type=img_types.DISPERSIVE)

                self.p.i_hf_raman = 182.
                                 
                self.p.v_pd_hf_tweezer_1064_rampdown3_end = {ramp_end}

                self.p.t_hf_tweezer_1064_rampdown3 = {t_evap}

                # self.xvar('frequency_raman_transition',147.4e6 + np.linspace(-50.e3,50.e3,15))

                self.p.frequency_raman_transition = 147245308.6053412 

                # self.xvar('amp_raman',np.linspace(0.1,.35,15))
                self.p.fraction_power_raman = .5

                # self.xvar('t_continuous_rabi',np.linspace(0.,400.e-6,10))
                self.p.t_continuous_rabi = 300.e-6
                
                # self.xvar('amp_imaging',np.linspace(0.1,.3,10))
                self.p.amp_imaging = .1

                self.p.hf_imaging_detuning = -570.e6 # 182.

                # self.xvar('hf_imaging_detuning_mid',np.arange(-700.,-580.,5)*1.e6)
                self.p.hf_imaging_detuning_mid = -640.e6 # -635.e6
                
                # self.xvar('dimension_slm_mask',np.linspace(15.e-6,250.e-6,10))
                self.p.dimension_slm_mask = 20.e-6

                # self.xvar('phase_slm_mask',np.linspace(0.,2.7*np.pi,15))
                self.p.phase_slm_mask = 0.9 * np.pi
                

                self.p.t_tweezer_hold = 20.e-3
                self.p.t_tof = 20.e-6
                self.p.t_mot_load = 1.0
                
                self.p.N_repeats = 10

                self.scope = self.scope_data.add_siglent_scope("192.168.1.108", label='PD', arm=False)

                self.finish_prepare(shuffle=True)

            @kernel
            def scan_kernel(self):

                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning_mid)
                # self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.slm.write_phase_mask_kernel(phase=self.p.phase_slm_mask,dimension=self.p.dimension_slm_mask)
                self.imaging.set_power(self.p.amp_imaging)

                self.prepare_hf_tweezers()

                self.raman.init(fraction_power = self.p.fraction_power_raman,
                                frequency_transition = self.p.frequency_raman_transition)

                self.ttl.raman_shutter.on()
                delay(10.e-3)
                self.ttl.line_trigger.wait_for_line_trigger()
                delay(4.7e-3)

                # self.raman.pulse(t=self.p.t_raman_stateprep_pulse)
                
                self.ttl.pd_scope_trig3.pulse(1.e-6)
                self.imaging.on()
                delay(5.e-6)
                self.raman.pulse(t=self.p.t_continuous_rabi)
                self.imaging.off()

                self.ttl.raman_shutter.off()
                
                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.imaging.set_power(.2,reset_pid=True)

                delay(self.p.t_tweezer_hold)
                self.tweezer.off()

                delay(self.p.t_tof)

                self.abs_image()

                self.core.wait_until_mu(now_mu())
                self.scope.read_sweep(0)
                self.core.break_realtime()
                delay(30.e-3)

            @kernel
            def run(self):
                self.init_kernel()
                self.load_2D_mot(self.p.t_2D_mot_load_delay)
                self.scan()
                self.mot_observe()

            def analyze(self):
                import os
                expt_filepath = os.path.abspath(__file__)
                # aprint(self.scope._data)
                self.end(expt_filepath)
                """)
        return script

# %%
eBuilder = ExptBuilder()

# %%
ramp_end = np.linspace(4.,9.,20)
t_evap = np.linspace(300.e-3,10.e-3,20)
# np.random.shuffle(ts)
for f in range(len(ramp_end)):
    print(t_evap[f],ramp_end[f])
    eBuilder.write_experiment_to_file(eBuilder.fringe_scan_expt(t_evap=t_evap[f],ramp_end=ramp_end[f]))
    eBuilder.run_expt()
# Out:
# 0.3 4.0
# 0 Run id: 60733
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060733_2026-03-08_16-46-37_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60733
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.2847368421052631 4.2631578947368425
# 0 Run id: 60734
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060734_2026-03-08_16-47-59_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60734
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.2694736842105263 4.526315789473684
# 0 Run id: 60735
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060735_2026-03-08_16-49-20_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60735
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.25421052631578944 4.7894736842105265
# 0 Run id: 60736
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060736_2026-03-08_16-50-42_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60736
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.23894736842105263 5.052631578947368
# 0 Run id: 60737
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060737_2026-03-08_16-52-04_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60737
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.22368421052631576 5.315789473684211
# 0 Run id: 60738
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060738_2026-03-08_16-53-25_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60738
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.20842105263157895 5.578947368421053
# 0 Run id: 60739
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060739_2026-03-08_16-54-48_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60739
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.19315789473684208 5.842105263157895
# 0 Run id: 60740
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060740_2026-03-08_16-56-08_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60740
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.17789473684210527 6.105263157894736
# 0 Run id: 60741
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060741_2026-03-08_16-57-28_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60741
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.1626315789473684 6.368421052631579
# 0 Run id: 60742
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060742_2026-03-08_16-58-48_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60742
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.14736842105263157 6.631578947368421
# 0 Run id: 60743
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060743_2026-03-08_17-00-08_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60743
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.13210526315789473 6.894736842105263
# 0 Run id: 60744
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060744_2026-03-08_17-01-28_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60744
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.11684210526315789 7.157894736842105
# 0 Run id: 60745
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060745_2026-03-08_17-02-49_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60745
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.10157894736842105 7.421052631578947
# 0 Run id: 60746
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060746_2026-03-08_17-04-09_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60746
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.0863157894736842 7.684210526315789
# 0 Run id: 60747
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060747_2026-03-08_17-05-29_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60747
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.07105263157894737 7.947368421052632
# 0 Run id: 60748
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060748_2026-03-08_17-06-49_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60748
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.05578947368421053 8.210526315789473
# 0 Run id: 60749
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060749_2026-03-08_17-08-09_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60749
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.04052631578947369 8.473684210526315
# 0 Run id: 60750
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060750_2026-03-08_17-09-28_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60750
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.02526315789473682 8.736842105263158
# 0 Run id: 60751
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060751_2026-03-08_17-10-47_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60751
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.01 9.0
# 0 Run id: 60752
#  10 values of dummy. 10 total shots. 30 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060752_2026-03-08_17-12-06_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60752
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.

# %%
relay = ethernet_relay

# %%
relay.source_off()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 relay.source_off()
#
# AttributeError: module 'waxx.control.ethernet_relay' has no attribute 'source_off'
