# %%
import numpy as np
from subprocess import PIPE, run
import matplotlib.pyplot as plt
import os
import textwrap
from waxx.control import ethernet_relay

class ExptBuilder():
    def __init__(self):
        self.__code_path__ = os.environ.get('code')
        self.__temp_exp_path__ = os.path.join(self.__code_path__, "k-exp", "kexp", "experiments", "ml_expt.py")

    def run_expt(self):
        expt_path = self.__temp_exp_path__
        run_expt_command = r"%kpy% & artiq_run " + expt_path
        result = run(run_expt_command, stdout=PIPE, stderr=PIPE, universal_newlines=True, shell=True)
        print(result.returncode, result.stdout, result.stderr)
        os.remove(self.__temp_exp_path__)
        return result.returncode
    
    def write_experiment_to_file(self, program):
        with open(self.__temp_exp_path__, 'w') as file:
            file.write(program)
    
    def fringe_scan_expt(self, t_evap, ramp_end):
        script = textwrap.dedent(f"""
        from artiq.experiment import *
        from artiq.experiment import delay
        from kexp import Base, img_types, cameras
        import numpy as np
        from kexp.calibrations.tweezer import tweezer_vpd1_to_vpd2
        from kexp.calibrations.imaging import high_field_imaging_detuning
        from artiq.coredevice.sampler import Sampler
        from artiq.language import now_mu
        from kexp.util.artiq.async_print import aprint

        class cont_mon_182_ref(EnvExperiment, Base):

            def prepare(self):
                Base.__init__(self,setup_camera=True,
                            camera_select=cameras.andor,
                            save_data=True,
                            imaging_type=img_types.DISPERSIVE)

                self.p.i_hf_raman = 182.
                                 
                self.p.v_pd_hf_tweezer_1064_rampdown2_end = {ramp_end}

                self.p.t_hf_tweezer_1064_rampdown2 = {t_evap}

                # self.xvar('frequency_raman_transition',147.4e6 + np.linspace(-50.e3,50.e3,15))

                self.p.frequency_raman_transition = 147245308.6053412

                # self.xvar('amp_raman',np.linspace(0.1,.35,15))
                self.p.fraction_power_raman = .5

                # self.xvar('t_continuous_rabi',np.linspace(0.,400.e-6,10))
                self.p.t_continuous_rabi = 300.e-6
                
                # self.xvar('amp_imaging',np.linspace(0.1,.3,10))
                self.p.amp_imaging = .1

                self.p.hf_imaging_detuning = -570.e6 # 182.

                # self.xvar('hf_imaging_detuning_mid',np.arange(-700.,-580.,5)*1.e6)
                self.p.hf_imaging_detuning_mid = -640.e6 # -635.e6
                
                # self.xvar('dimension_slm_mask',np.linspace(15.e-6,250.e-6,10))
                self.p.dimension_slm_mask = 20.e-6

                # self.xvar('phase_slm_mask',np.linspace(0.,2.7*np.pi,15))
                self.p.phase_slm_mask = 0.9 * np.pi
                

                self.p.t_tweezer_hold = 20.e-3
                self.p.t_tof = 20.e-6
                self.p.t_mot_load = 1.0
                
                self.p.N_repeats = 5

                self.scope = self.scope_data.add_siglent_scope("192.168.1.108", label='PD', arm=False)

                self.finish_prepare(shuffle=True)

            @kernel
            def scan_kernel(self):

                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning_mid)
                # self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.slm.write_phase_mask_kernel(phase=self.p.phase_slm_mask,dimension=self.p.dimension_slm_mask)
                self.imaging.set_power(self.p.amp_imaging)

                self.prepare_hf_tweezers()

                self.raman.init(fraction_power = self.p.fraction_power_raman,
                                frequency_transition = self.p.frequency_raman_transition)

                self.ttl.raman_shutter.on()
                delay(10.e-3)
                self.ttl.line_trigger.wait_for_line_trigger()
                delay(4.7e-3)

                # self.raman.pulse(t=self.p.t_raman_stateprep_pulse)
                
                self.ttl.pd_scope_trig3.pulse(1.e-6)
                self.imaging.on()
                delay(5.e-6)
                self.raman.pulse(t=self.p.t_continuous_rabi)
                self.imaging.off()

                self.ttl.raman_shutter.off()
                
                self.set_imaging_detuning(frequency_detuned = self.p.hf_imaging_detuning)
                self.imaging.set_power(.2,reset_pid=True)

                delay(self.p.t_tweezer_hold)
                self.tweezer.off()

                delay(self.p.t_tof)

                self.abs_image()

                self.core.wait_until_mu(now_mu())
                self.scope.read_sweep(0)
                self.core.break_realtime()
                delay(30.e-3)

            @kernel
            def run(self):
                self.init_kernel()
                self.load_2D_mot(self.p.t_2D_mot_load_delay)
                self.scan()
                self.mot_observe()

            def analyze(self):
                import os
                expt_filepath = os.path.abspath(__file__)
                # aprint(self.scope._data)
                self.end(expt_filepath)
                """)
        return script

# %%
eBuilder = ExptBuilder()

# %%
ramp_end = np.linspace(.16,.99,20)
t_evap = np.linspace(500.e-3,10.e-3,20)
# np.random.shuffle(ts)
for f in range(len(ramp_end)):
    print(t_evap[f],ramp_end[f])
    eBuilder.write_experiment_to_file(eBuilder.fringe_scan_expt(t_evap=t_evap[f],ramp_end=ramp_end[f]))
    eBuilder.run_expt()
# Out:
# 0.5 0.16
# 0 Run id: 60753
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060753_2026-03-08_17-14-27_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60753
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.47421052631578947 0.2036842105263158
# 0 Run id: 60754
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060754_2026-03-08_17-15-14_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60754
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.44842105263157894 0.24736842105263157
# 0 Run id: 60755
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060755_2026-03-08_17-16-01_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60755
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.4226315789473684 0.29105263157894734
# 0 Run id: 60756
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060756_2026-03-08_17-16-49_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60756
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.3968421052631579 0.33473684210526317
# 0 Run id: 60757
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060757_2026-03-08_17-17-34_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60757
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.3710526315789474 0.378421052631579
# 0 Run id: 60758
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060758_2026-03-08_17-18-20_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60758
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.3452631578947368 0.42210526315789476
# 0 Run id: 60759
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060759_2026-03-08_17-19-06_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60759
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.31947368421052635 0.46578947368421053
# 0 Run id: 60760
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060760_2026-03-08_17-19-54_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60760
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.29368421052631577 0.5094736842105263
# 0 Run id: 60761
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060761_2026-03-08_17-20-40_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60761
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.2678947368421053 0.5531578947368421
# 0 Run id: 60762
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060762_2026-03-08_17-21-25_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60762
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.24210526315789477 0.596842105263158
# 0 Run id: 60763
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060763_2026-03-08_17-22-10_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60763
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.21631578947368424 0.6405263157894737
# 0 Run id: 60764
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060764_2026-03-08_17-22-54_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60764
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.1905263157894737 0.6842105263157895
# 0 Run id: 60765
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060765_2026-03-08_17-23-39_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60765
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.16473684210526318 0.7278947368421053
# 0 Run id: 60766
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060766_2026-03-08_17-24-25_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60766
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.13894736842105265 0.7715789473684211
# 0 Run id: 60767
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060767_2026-03-08_17-25-09_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60767
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.11315789473684212 0.8152631578947369
# 0 Run id: 60768
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060768_2026-03-08_17-25-53_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60768
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.0873684210526316 0.8589473684210527
# 0 Run id: 60769
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060769_2026-03-08_17-26-37_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60769
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.061578947368421066 0.9026315789473685
# 0 Run id: 60770
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060770_2026-03-08_17-27-20_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60770
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.03578947368421054 0.9463157894736842
# 0 Run id: 60771
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060771_2026-03-08_17-28-04_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60771
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.
#
# 0.01 0.99
# 0 Run id: 60772
#  5 values of dummy. 5 total shots. 15 total images expected.
# B:\_K\PotassiumData\2026-03-08\0060772_2026-03-08_17-28-48_cont_mon_182_ref.hdf5
# Acknowledged camera ready signal.
# Camera is ready.
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#  Run ID: 60772
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
#
# Sent: {'mask': 'spot', 'center': [993, 820], 'phase': 0.9, 'dimension': 20, 'initialize': False, 'spacing': 10, 'angle': 45}
# -> mask: spot, dimension = 20 um, phase = 0.9 pi, x-center = 993, y-center = 820
#
# Parameters saved, data closed.
# Done!
# Device states updated.

# %%
relay = ethernet_relay

# %%
relay.source_off()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 relay.source_off()
#
# AttributeError: module 'waxx.control.ethernet_relay' has no attribute 'source_off'
